# %% [markdown]
# # Background & Objectives
# The goal of this challenge is to query the database from our Python code.

# %% [markdown]
# # Data
# We will work with the movies.sqlite database available at this URL:
# https://wagon-public-datasets.s3.amazonaws.com/sql_databases/movies.sqlite

# %% [markdown]
# # Investigating the database

# %% [markdown]
# ## Creating the connection and cursor

# %%
import sqlite3
import pandas as pd

connection = sqlite3.connect('data/movies.sqlite')
connection.row_factory = sqlite3.Row
cursor = connection.cursor()

# %% [markdown]
# ## Finding the tables in the database

# %%
def database_explorer(db_cursor):
    """ Shows the number of tables in the database"""

    query = """
            SELECT name FROM sqlite_master  
            WHERE type='table';
            """
    db_cursor.execute(query)
    rows = db_cursor.fetchall()

    print(f"""
    {type(rows) = }
    {len(rows) = }
    """)

    return [row[row.keys()[0]] for row in rows]

database_explorer(db_cursor=cursor)
# Out:
#     type(rows) = <class 'list'>
#     len(rows) = 3
# ['sqlite_sequence', 'directors', 'movies']

# %% [markdown]
# ## Searching for the amount of directors in the database

# %%
def directors_count(db_cursor):
    """return the number of directors contained in the database"""

    query = """
            SELECT COUNT(*) AS directors_count
            FROM directors;
            """

    db_cursor.execute(query)
    rows = db_cursor.fetchall()

    print(f"""
    {type(rows) = }
    {len(rows) = }
    {[row.keys() for row in rows] = }
    """)

    return [row[row.keys()[0]] for row in rows][0]

directors_count(db_cursor=cursor)
# Out:
#     type(rows) = <class 'list'>
#     len(rows) = 1
#     [row.keys() for row in rows] = [['directors_count']]
# 4089

# %% [markdown]
# ## Obtaining  a list of all directors in the database

# %%
def directors_list(db_cursor):
    """return the list of all the directors sorted in alphabetical order"""

    query = """
                SELECT directors.name  
                FROM directors
                ORDER BY directors.name ASC;
                """

    db_cursor.execute(query)
    rows = db_cursor.fetchall()

    print(f"""
    {type(rows) = }
    {len(rows) = }
    {[row.keys() for row in rows][0] = }
    """)

    return [row[row.keys()[0]] for row in rows]

directors_list(db_cursor=cursor)
# Out:
#     type(rows) = <class 'list'>
#     len(rows) = 4089
#     [row.keys() for row in rows][0] = ['name']
# ['A.R. Murugadoss',
#  'Aamir Khan',
#  'Aanand L. Rai',
#  'Aaron Hann',
#  'Aaron Harvey',
#  'Aaron Horvath',
#  'Aaron Lipstadt',
#  'Aaron Moorhead',
#  'Aaron Schneider',
#  'Aaron Seltzer',
#  'Aaron Sorkin',
#  'Aaron Springer',
#  'Abbas Alibhai Burmawalla',
#  'Abbas Kiarostami',
#  'Abbas Tyrewala',
#  'Abby Kohn',
#  'Abdellatif Kechiche',
#  'Abderrahmane Sissako',
#  'Abe Sylvia',
#  'Abel Ferrara',
#  'Abhinav Kashyap',
#  'Abhinay Deo',
#  'Abhishek Chaubey',
#  'Abhishek Kapoor',
#  'Abhishek Sharma',
#  'Abhishek Varman',
#  'Abram Cox',
#  'Adam Arkin',
#  'Adam Bernstein',
#  'Adam Brooks',
#  'Adam Davidson',
#  'Adam Elliot',
#  'Adam Green',
#  'Adam Jay Epstein',
#  'Adam Kassen',
#  'Adam MacDonald',
#  'Adam Marcus',
#  'Adam McKay',
#  'Adam Paloian',
#  'Adam Randall',
#  'Adam Rifkin',
#  'Adam Robitel',
#  'Adam Schindler',
#  'Adam Shankman',
#  'Adam Weissman',
#  'Adam Wingard',
#  'Adesh Prasad',
#  'Aditya Chopra',
#  'Aditya Datt',
#  'Aditya Dhar',
#  'Adrian Grunberg',
#  'Adrian Lyne',
#  'Adrian Molina',
#  'Adrian Shergold',
#  'Adrienne Shelly',
#  'Advait Chandan',
#  'Afonso Poyart',
#  'Agnieszka Holland',
#  'Agnieszka Wojtowicz-Vosloo',
#  'Agnès Varda',
#  'Agustín Díaz Yanes',
#  'Aharon Keshales',
#  'Aisling Walsh',
#  'Aki Kaurismäki',
#  'Akira Kurosawa',
#  'Akitsugu Hisagi',
#  'Akiva Goldsman',
#  'Akiva Schaffer',
#  'Alain Chabat',
#  'Alain Desrochers',
#  'Alain Guiraudie',
#  'Alain Resnais',
#  'Alan Ball',
#  'Alan Barillaro',
#  'Alan Carter',
#  'Alan Cohn',
#  'Alan Grint',
#  'Alan J. Levi',
#  'Alan J. Pakula',
#  'Alan Mak',
#  'Alan Metter',
#  'Alan Myerson',
#  'Alan Parker',
#  'Alan Poul',
#  'Alan Rafkin',
#  'Alan Rickman',
#  'Alan Shapiro',
#  'Alan Taylor',
#  'Alan Yang',
#  'Alastair Fothergill',
#  'Albert Brooks',
#  'Albert Calleros',
#  'Albert Hughes',
#  'Albert Lamorisse',
#  'Albert Lewin',
#  'Albert Magnoli',
#  'Albert Pyun',
#  'Alberto Mielgo',
#  'Alberto Rodríguez',
#  'Alejandro Agresti',
#  'Alejandro Amenábar',
#  'Alejandro G. Iñárritu',
#  'Alejandro Jodorowsky',
#  'Alejandro Monteverde',
#  'Alek Keshishian',
#  'Aleksander Bach',
#  'Aleksandr Sokurov',
#  'Aleksey Balabanov',
#  'Aleksey Pimanov',
#  'Alessandro Carloni',
#  'Alex Brewer',
#  'Alex Cox',
#  'Alex Garland',
#  'Alex Gibney',
#  'Alex Graves',
#  'Alex Gregory',
#  'Alex Hall',
#  'Alex Hardcastle',
#  'Alex Kendrick',
#  'Alex Kurtzman',
#  'Alex Lehmann',
#  'Alex Proyas',
#  'Alex Richanbach',
#  'Alex Winckler',
#  'Alex Zakrzewski',
#  'Alex Zamm',
#  'Alex van Warmerdam',
#  'Alexander Mackendrick',
#  'Alexander Payne',
#  'Alexander Witt',
#  'Alexandre Aja',
#  'Alexandre Amancio',
#  'Alexandre Avancini',
#  'Alexandre Bustillo',
#  'Alexandros Avranas',
#  'Alfonso Arau',
#  'Alfonso Cuarón',
#  'Alfonso Gomez-Rejon',
#  'Alfonso Ribeiro',
#  'Alfred Gimeno',
#  'Alfred Hitchcock',
#  'Ali Abbas Zafar',
#  'Ali Abbasi',
#  'Ali Atay',
#  'Ali Taner Baltaci',
#  'Alice Dallow',
#  'Alice Troughton',
#  'Alik Sakharov',
#  'Alison Maclean',
#  'Alister Grierson',
#  'Allan A. Goldstein',
#  'Allan Arkush',
#  'Allan Cubitt',
#  'Allan Kartun',
#  'Allan Kroeker',
#  'Allan Moyle',
#  'Allen Coulter',
#  'Allen Hughes',
#  'Allison Anders',
#  'Allison Burnett',
#  'Allison Liddi-Brown',
#  'Alper Caglar',
#  'Alphonse Puthren',
#  'Alrick Riley',
#  'Amar Kaushik',
#  'Ami Canaan Mann',
#  'Amit Golani',
#  'Amit Masurkar',
#  'Amit Ravindernath Sharma',
#  'Amitabh Reza Chowdhury',
#  'Amma Asante',
#  'Amol Palekar',
#  'Amy Heckerling',
#  'Amy Hennig',
#  'Amy Hudson',
#  'Amy Poehler',
#  'Amy Sherman-Palladino',
#  'Amy Winfrey',
#  'Amyn Kaderali',
#  'Ana Lily Amirpour',
#  'Anand Tucker',
#  'Anders Engström',
#  'Anders Thomas Jensen',
#  'Anders Walter',
#  'Andrea Arnold',
#  'Andrea Di Stefano',
#  'Andreas Prochaska',
#  'Andrei Tarkovsky',
#  'Andrew Adamson',
#  'Andrew Bergman',
#  'Andrew Bernstein',
#  'Andrew Currie',
#  'Andrew Davis',
#  'Andrew Dominik',
#  'Andrew Douglas',
#  'Andrew Erwin',
#  'Andrew Fleming',
#  'Andrew Gunn',
#  'Andrew Haigh',
#  'Andrew Jarecki',
#  'Andrew Jay Cohen',
#  'Andrew L. Schmidt',
#  'Andrew Lau',
#  'Andrew McCarthy',
#  'Andrew Mogel',
#  'Andrew Morahan',
#  'Andrew Niccol',
#  'Andrew Sipes',
#  'Andrew Stanton',
#  'Andrew Traucki',
#  'Andrew V. McLaglen',
#  'Andrew Waller',
#  'Andrey Konchalovskiy',
#  'Andrey Zvyagintsev',
#  'Andrzej Bartkowiak',
#  'Andrzej Sekula',
#  'Andrzej Wajda',
#  'Andrzej Zulawski',
#  'André De Toth',
#  'André Øvredal',
#  'Andrés Baiz',
#  'Andrés Wood',
#  'Andy Ackerman',
#  'Andy Barsh',
#  'Andy Cadiff',
#  'Andy De Emmony',
#  'Andy Fickman',
#  'Andy Goddard',
#  'Andy Hamilton',
#  'Andy Hay',
#  'Andy Mikita',
#  'Andy Morris',
#  'Andy Muschietti',
#  'Andy Serkis',
#  'Andy Tennant',
#  'Andy Wilson',
#  'Andy Wolk',
#  'Anees Bazmee',
#  'Aneesh Chaganty',
#  'Ang Lee',
#  'Angel Gracia',
#  'Angela Robinson',
#  'Angelina Jolie',
#  'Angus MacLane',
#  'Anh Hung Tran',
#  'Aniruddha Roy Chowdhury',
#  'Anjali Menon',
#  'Ann Druyan',
#  'Anna Boden',
#  'Anna Foerster',
#  'Anna Muylaert',
#  'Anna Rose Holmer',
#  'Annabel Jankel',
#  'Anne Fletcher',
#  'Anne Fontaine',
#  'Anne Sewitsky',
#  'Annie Griffin',
#  'Anson Williams',
#  'Anthony Bell',
#  'Anthony Burns',
#  'Anthony Byrne',
#  'Anthony C. Ferrante',
#  'Anthony Chun',
#  'Anthony DiBlasi',
#  'Anthony Harvey',
#  'Anthony Hemingway',
#  'Anthony Hickox',
#  'Anthony Mann',
#  'Anthony Maras',
#  'Anthony Minghella',
#  'Anthony Perkins',
#  'Anthony Pullen Shaw',
#  'Anthony Russo',
#  'Anthony Waller',
#  'Anthony Wonke',
#  'Antoine Fuqua',
#  'Anton Corbijn',
#  'Antonia Bird',
#  'Antonio Campos',
#  'Antonio Negret',
#  'Antony Hoffman',
#  'Antti Jokinen',
#  'Anubhav Sinha',
#  'Anup Bhandari',
#  'Anurag Basu',
#  'Anurag Kashyap',
#  'Anurag Singh',
#  'Anusha Rizvi',
#  'Apichatpong Weerasethakul',
#  'Apoorv Singh Karki',
#  'Aram Rappaport',
#  'Arbaaz Khan',
#  'Archie Mayo',
#  'Ari Aster',
#  'Ari Folman',
#  'Ari Sandel',
#  'Arie Posin',
#  'Ariel Schulman',
#  'Ariel Vromen',
#  'Ariel Zeitoun',
#  'Aristomenis Tsirbas',
#  'Armando Iannucci',
#  'Arne Glimcher',
#  'Art Linson',
#  'Arthur Allan Seidelman',
#  'Arthur Davis',
#  'Arthur Forrest',
#  'Arthur Hiller',
#  'Arthur Penn',
#  'Arthur Qwak',
#  'Arthur Rankin Jr.',
#  'Arvin Brown',
#  'Asger Leth',
#  'Asghar Farhadi',
#  'Ash Brannon',
#  'Ashley Way',
#  'Ashraf Ismail',
#  'Ashutosh Gowariker',
#  'Ashwiny Iyer Tiwari',
#  'Asif Kapadia',
#  'Assaf Bernstein',
#  'Ate de Jong',
#  'Atif Yilmaz',
#  'Atlee Kumar',
#  'Atom Egoyan',
#  'Audrey Cooke',
#  'Audrey Wells',
#  'Ava DuVernay',
#  'Ayan Mukherjee',
#  'Aytaç Agirlar',
#  'Aziz Mirza',
#  'Babak Anvari',
#  'Babak Najafi',
#  'Bahman Ghobadi',
#  'Baillie Walsh',
#  'Baltasar Kormákur',
#  'Banjong Pisanthanakun',
#  'Banksy',
#  'Baran bo Odar',
#  'Barbara Brown',
#  'Barbara Kopple',
#  'Barbara Schroeder',
#  'Barbet Schroeder',
#  'Barbra Streisand',
#  'Barry Battles',
#  'Barry Cook',
#  'Barry Jenkins',
#  'Barry Levinson',
#  'Barry Skolnick',
#  'Barry Sonnenfeld',
#  'Barry W. Blaustein',
#  'Bart Freundlich',
#  'Bart Layton',
#  'Baz Luhrmann',
#  'Becky Martin',
#  'Beeban Kidron',
#  'Bejoy Nambiar',
#  'Ben Affleck',
#  'Ben Bolt',
#  'Ben C. Lucas',
#  'Ben Falcone',
#  'Ben Feldman',
#  'Ben Gluck',
#  'Ben Howling',
#  'Ben Ketai',
#  'Ben Lewin',
#  'Ben Palmer',
#  'Ben Ramsey',
#  'Ben Stiller',
#  'Ben Taylor',
#  'Ben Wheatley',
#  'Ben Young',
#  'Ben Younger',
#  'Benedek Fliegauf',
#  'Benh Zeitlin',
#  'Benjamin Caron',
#  'Benjamin Christensen',
#  'Benjamin Statler',
#  'Bennett Miller',
#  'Benny Boom',
#  'Benny Chan',
#  'Benny Safdie',
#  'Benoit Richer',
#  'Bent Hamer',
#  'Bernard Derriman',
#  'Bernard McEveety',
#  'Bernard Rose',
#  'Bernard Wiesen',
#  'Bernardo Bertolucci',
#  'Bertram van Munster',
#  'Bertrand Tavernier',
#  'Beth McCarthy-Miller',
#  'Bethany Ashton Wolf',
#  'Bethany Rooney',
#  'Betty Thomas',
#  'Bharat Nalluri',
#  'Bibo Bergeron',
#  'Bigas Luna',
#  'Bilal Lashari',
#  'Bill Condon',
#  "Bill D'Elia",
#  'Bill Duke',
#  'Bill Eagles',
#  'Bill Forsyth',
#  'Bill Hader',
#  'Bill Holderman',
#  'Bill Kroyer',
#  'Bill Melendez',
#  'Bill Paxton',
#  'Bill Pohlad',
#  'Bill Wolf',
#  'Bille August',
#  'Bille Woodruff',
#  'Billy Bob Thornton',
#  'Billy Corben',
#  'Billy Crystal',
#  'Billy Gierhart',
#  "Billy O'Brien",
#  'Billy Ray',
#  'Billy Wilder',
#  'Biswapati Sarkar',
#  'Björn Runge',
#  'Blair Hayes',
#  'Blake Edwards',
#  'Bo Burnham',
#  'Bo Welch',
#  'Bo Zenga',
#  'Boaz Yakin',
#  'Bob Arkwright',
#  'Bob Camp',
#  'Bob Clark',
#  'Bob Dolman',
#  'Bob Fosse',
#  'Bob Gale',
#  'Bob Hathcock',
#  'Bob Koherr',
#  'Bob Odenkirk',
#  'Bob Rafelson',
#  'Bob Richardson',
#  'Bob Saget',
#  'Bob Spiers',
#  'Bobby Farrelly',
#  'Bobby Roth',
#  'Bobcat Goldthwait',
#  'Bong Hee Han',
#  'Bonnie Hunt',
#  'Boots Riley',
#  'Bora Dagtekin',
#  'Boris Sagal',
#  'Boyd Kirkland',
#  'Brad Abrams',
#  'Brad Anderson',
#  'Brad Bird',
#  'Brad Furman',
#  'Brad Kreisberg',
#  'Brad Peyton',
#  'Brad Silberling',
#  'Brad Turner',
#  'Bradley Buecker',
#  'Bradley Cooper',
#  'Bradley King',
#  'Bradley Parker',
#  'Bradley Raymond',
#  'Bradley Walsh',
#  'Brady Corbet',
#  'Brandon Camp',
#  'Brandon Cronenberg',
#  'Brandon Vietti',
#  'Breck Eisner',
#  'Brendan Malloy',
#  'Brendan McNamara',
#  'Brent Bonacorso',
#  'Brent Maddock',
#  'Bret Haaland',
#  'Brett Leonard',
#  'Brett Morgen',
#  'Brett Ratner',
#  'Brett Simon',
#  'Brett Sullivan',
#  'Brian A. Miller',
#  'Brian Dannelly',
#  'Brian De Palma',
#  'Brian DeCubellis',
#  'Brian Desmond Hurst',
#  'Brian Fee',
#  'Brian G. Hutton',
#  'Brian Gibson',
#  'Brian Gilbert',
#  'Brian Goodman',
#  'Brian Helgeland',
#  'Brian Henson',
#  'Brian Kirk',
#  'Brian Klein',
#  'Brian Klugman',
#  'Brian Knappenberger',
#  'Brian Koppelman',
#  'Brian Levant',
#  'Brian McGinn',
#  'Brian Percival',
#  'Brian Robbins',
#  'Brian Smrz',
#  'Brian Strachan',
#  'Brian Taylor',
#  'Brian Welsh',
#  'Brian Yuzna',
#  'Brie Larson',
#  'Brin Hill',
#  'Bronwen Hughes',
#  'Brooke Kennedy',
#  'Bruce A. Evans',
#  'Bruce Beresford',
#  'Bruce Campbell',
#  'Bruce Goodison',
#  'Bruce Gowers',
#  'Bruce Hendricks',
#  'Bruce Hunt',
#  'Bruce Lee',
#  'Bruce Malmuth',
#  'Bruce McCulloch',
#  'Bruce McDonald',
#  'Bruce Robinson',
#  'Bruno Barreto',
#  'Bruno Bianchi',
#  'Bryan Bertino',
#  'Bryan Cranston',
#  'Bryan Fogel',
#  'Bryan Forbes',
#  'Bryan Fordney',
#  'Bryan Gordon',
#  'Bryan Singer',
#  'Bryan Spicer',
#  'Bryn Higgins',
#  'Bud Kremp',
#  'Bud Luckey',
#  'Buddy Van Horn',
#  'Burak Aksak',
#  'Burr Steers',
#  'Buster Keaton',
#  'Butch Lukic',
#  'Byron Haskin',
#  'Byron Howard',
#  'Béla Tarr',
#  'Börkur Sigþórsson',
#  'C. Jay Cox',
#  'C. Prem Kumar',
#  'C.B. Harding',
#  'Cal Brunker',
#  'Callie Khouri',
#  'Cameron Crowe',
#  'Camille Delamarre',
#  'Can Ulkay',
#  'Caradog W. James',
#  'Carl Franklin',
#  'Carl Reiner',
#  'Carl Rinsch',
#  'Carl Schultz',
#  'Carl Theodor Dreyer',
#  'Carl Tibbetts',
#  'Carles Torrens',
#  'Carlo Carlei',
#  'Carlo Ledesma',
#  'Carlos Carrera',
#  'Carlos López Estrada',
#  'Carlos Saldanha',
#  'Carlton Cuse',
#  'Carol Banker',
#  'Carol Millican',
#  'Carol Reed',
#  'Caroline Labrèche',
#  'Caroline Link',
#  'Carroll Ballard',
#  'Carter Smith',
#  'Cary Joji Fukunaga',
#  'Cary Solomon',
#  'Casey Affleck',
#  'Casey Hudson',
#  'Casey La Scala',
#  'Cate Shortland',
#  'Catherine Hardwicke',
#  'Catherine Millar',
#  'Cathy Malkasian',
#  'Cecil B. DeMille',
#  'Cedric Nicolas-Troyan',
#  'Celal Çimen',
#  'Cem Yilmaz',
#  'Cesc Gay',
#  'Ceyda Torun',
#  'Chad Stahelski',
#  'Chan-wook Park',
#  'Chandra Barot',
#  'Chang-dong Lee',
#  'Chapman Way',
#  'Charles A. Nichols',
#  'Charles Barton',
#  'Charles Beeson',
#  'Charles Binamé',
#  'Charles Chaplin',
#  'Charles Correll',
#  'Charles Crichton',
#  'Charles Dance',
#  'Charles E. Sellier Jr.',
#  'Charles Ferguson',
#  'Charles Guard',
#  'Charles Haid',
#  'Charles Herman-Wurmfeld',
#  'Charles Laughton',
#  'Charles Martin',
#  'Charles Martin Smith',
#  'Charles Reisner',
#  'Charles S. Dubin',
#  'Charles Shyer',
#  'Charles Stone III',
#  'Charles Vidor',
#  'Charles Walters',
#  'Charlie Bean',
#  'Charlie Kaufman',
#  'Charlie McDowell',
#  'Cheol-soo Jang',
#  'Chi-Hwa Chen',
#  'Chia-Hsiang Wu',
#  'Chia-Liang Liu',
#  'China Moo-Young',
#  'Chiwetel Ejiofor',
#  'Chloe Thomas',
#  'Chloé Zhao',
#  'Chris Addison',
#  'Chris Bailey',
#  'Chris Bell',
#  'Chris Buck',
#  'Chris Butler',
#  'Chris Carter',
#  'Chris Columbus',
#  'Chris Evans',
#  'Chris Fisher',
#  'Chris Gerolmo',
#  'Chris Gorak',
#  'Chris Kentis',
#  'Chris Koch',
#  'Chris Lofing',
#  'Chris Long',
#  'Chris Marker',
#  'Chris McKay',
#  'Chris Miller',
#  'Chris Moukarbel',
#  'Chris Nahon',
#  'Chris Nelson',
#  'Chris Noonan',
#  'Chris Paine',
#  'Chris Peckover',
#  'Chris Ray',
#  'Chris Renaud',
#  'Chris Roberts',
#  'Chris Robinson',
#  'Chris Rock',
#  'Chris Sanders',
#  'Chris Shadley',
#  'Chris Sivertson',
#  'Chris Smith',
#  'Chris Stokes',
#  'Chris Terrio',
#  'Chris Walas',
#  'Chris Wedge',
#  'Chris Weitz',
#  'Christian Alvart',
#  'Christian Cantamessa',
#  'Christian Carion',
#  'Christian Ditter',
#  'Christian Duguay',
#  'Christian E. Christiansen',
#  'Christian Gudegast',
#  'Christian Nyby',
#  'Christian Petzold',
#  'Christian Rivers',
#  'Christian Volckman',
#  'Christian Zübert',
#  'Christine Gernon',
#  'Christine Jeffs',
#  'Christophe Barratier',
#  'Christophe Gans',
#  'Christopher Berkeley',
#  'Christopher Cain',
#  'Christopher Caldwell',
#  'Christopher Chulack',
#  'Christopher Guest',
#  'Christopher Kenneally',
#  'Christopher Landon',
#  'Christopher Leitch',
#  'Christopher Leone',
#  'Christopher McCulloch',
#  'Christopher McQuarrie',
#  'Christopher Miller',
#  'Christopher Misiano',
#  'Christopher Monger',
#  'Christopher Morahan',
#  'Christopher Morris',
#  'Christopher Nolan',
#  'Christopher Smith',
#  'Christopher Spencer',
#  'Chuck Bowman',
#  'Chuck Jones',
#  'Chuck Russell',
#  'Chuck Sheetz',
#  'Ciaran Donnelly',
#  'Ciarán Foy',
#  'Ciro Guerra',
#  'Ciro Nieli',
#  'Claire Denis',
#  'Claire Scanlon',
#  'Clare Kilner',
#  'Clark Gregg',
#  'Clark Johnson',
#  'Claude Barras',
#  'Claude Berri',
#  'Claude Nuridsany',
#  'Claude Zidi',
#  'Claudio Fragasso',
#  'Clay Jeter',
#  'Clay Kaytis',
#  'Clayton Boen',
#  'Clement Virgo',
#  'Cliff Bole',
#  'Clint Eastwood',
#  'Clio Barnard',
#  'Clive Barker',
#  'Clive Donner',
#  'Clyde Geronimi',
#  'Cody Cameron',
#  'Coky Giedroyc',
#  'Colin Bucksey',
#  'Colin Budds',
#  'Colin Higgins',
#  'Colin Minihan',
#  'Colin Strause',
#  'Colin Teague',
#  'Colin Trevorrow',
#  'Colm McCarthy',
#  'Conrad Vernon',
#  'Coralie Fargeat',
#  'Corey Yuen',
#  'Corin Hardy',
#  'Cory Barlog',
#  'Cory Finley',
#  'Costa-Gavras',
#  'Courteney Cox',
#  'Courtney Hunt',
#  'Courtney Rowe',
#  'Courtney Solomon',
#  'Craig Brewer',
#  'Craig Gillespie',
#  'Craig Johnson',
#  'Craig Mazin',
#  'Craig McCracken',
#  'Craig Moss',
#  'Craig Powell',
#  'Craig Pryce',
#  'Craig R. Baxley',
#  'Craig Rosenberg',
#  'Craig Viveiros',
#  'Craig Zisk',
#  'Craig Zobel',
#  'Crispian Mills',
#  'Crispin Reece',
#  'Cristi Puiu',
#  'Cristian Mungiu',
#  'Crystal Moselle',
#  'Curt Geda',
#  'Curtis Hanson',
#  'Cy Endfield',
#  'Cyrus Nowrasteh',
#  'Cédric Jimenez',
#  'Cédric Klapisch',
#  'Céline Sciamma',
#  'D. Kerry Prior',
#  'D.B. Weiss',
#  'D.J. Caruso',
#  'D.J. MacHale',
#  'D.W. Griffith',
#  'Daisuke Chiba',
#  'Daisuke Nishio',
#  'Daisy von Scherler Mayer',
#  'Dale Launer',
#  'Dalton Trumbo',
#  'Damian Nieman',
#  'Damien Chazelle',
#  'Damien Dante Wayans',
#  'Damien Macé',
#  "Damien O'Donnell",
#  'Damián Szifron',
#  'Damon Beesley',
#  'Damon Santostefano',
#  'Damon Thomas',
#  'Dan Aykroyd',
#  'Dan Bradley',
#  'Dan Bush',
#  'Dan Cutforth',
#  'Dan Fausett',
#  'Dan Fogelman',
#  'Dan Fraga',
#  'Dan Gilroy',
#  'Dan Kwan',
#  'Dan Mazer',
#  "Dan O'Bannon",
#  'Dan Povenmire',
#  'Dan Reed',
#  'Dan Riba',
#  'Dan Rush',
#  'Dan Scanlon',
#  'Dan Trachtenberg',
#  'Daniel Alfredson',
#  'Daniel Algrant',
#  'Daniel Attias',
#  'Daniel Barber',
#  'Daniel Barnz',
#  'Daniel Benmayor',
#  'Daniel Cohen',
#  'Daniel Espinosa',
#  'Daniel Goldhaber',
#  'Daniel Gray Longino',
#  'Daniel J. Goor',
#  'Daniel Lee',
#  'Daniel Minahan',
#  'Daniel Monzón',
#  'Daniel Myrick',
#  'Daniel Nettheim',
#  'Daniel Petrie',
#  'Daniel Petrie Jr.',
#  'Daniel Ragussis',
#  'Daniel Rezende',
#  'Daniel Ribeiro',
#  'Daniel Sackheim',
#  'Daniel Schechter',
#  'Daniel Stamm',
#  'Daniel Stern',
#  'Daniel Waters',
#  'Danis Tanovic',
#  'Danny Boyle',
#  'Danny Cannon',
#  'Danny DeVito',
#  'Danny Kallis',
#  'Danny Leiner',
#  'Danny Pang',
#  'Danny Steinmann',
#  'Dany Boon',
#  'Dario Argento',
#  'Dario Piana',
#  'Darnell Martin',
#  'Darrell Rooney',
#  'Darren Aronofsky',
#  'Darren Doane',
#  'Darren Grant',
#  'Darren Lynn Bousman',
#  'Darren Paul Fisher',
#  'Darren Stein',
#  'Dave Anthony',
#  'Dave Bullock',
#  'Dave Diomedi',
#  'Dave Filoni',
#  'Dave Green',
#  'Dave Grohl',
#  'Dave McCary',
#  'Dave McKean',
#  'Dave Meyers',
#  'Dave Powers',
#  'Dave Willis',
#  'David Alexanian',
#  'David Anspaugh',
#  'David Atkins',
#  'David Ayer',
#  'David Barrett',
#  'David Benioff',
#  'David Bowers',
#  'David Brooks',
#  'David Bruckner',
#  'David Cage',
#  'David Carson',
#  'David Croft',
#  'David Cronenberg',
#  'David Dhawan',
#  'David Dobkin',
#  'David Evans',
#  'David F. Sandberg',
#  'David Farr',
#  'David Farrier',
#  'David Fincher',
#  'David Foenkinos',
#  'David Frankel',
#  'David Frazee',
#  'David Geddes',
#  'David Gelb',
#  'David Gordon Green',
#  'David Grossman',
#  'David Grovic',
#  'David Guy Levy',
#  'David Hackl',
#  'David Hare',
#  'David Hogan',
#  'David J. Burke',
#  'David Jacobson',
#  'David Jung',
#  'David Kellogg',
#  'David Kerr',
#  'David Koepp',
#  'David L. Cunningham',
#  'David Lane',
#  'David Lean',
#  'David Lee',
#  'David Leitch',
#  'David Livingston',
#  'David Lowery',
#  'David Lynch',
#  'David M. Rosenthal',
#  'David Mackay',
#  'David Mackenzie',
#  'David Mamet',
#  'David McNally',
#  'David McWhirter',
#  'David Michener',
#  'David Michôd',
#  'David Mickey Evans',
#  'David Mirkin',
#  'David Moreau',
#  'David Nerlich',
#  'David Nutter',
#  'David O. Russell',
#  'David Palmer',
#  'David Pastor',
#  'David Petrarca',
#  'David R. Ellis',
#  'David Robert Mitchell',
#  'David Ross',
#  'David S. Goyer',
#  'David S. Ward',
#  'David Sandberg',
#  'David Schwimmer',
#  'David Seltzer',
#  'David Siegel',
#  'David Silverman',
#  'David Slade',
#  'David Solomon',
#  'David Soren',
#  'David Speyrer',
#  'David Straiton',
#  'David Swift',
#  'David Trainer',
#  'David Twohy',
#  'David Von Ancken',
#  'David Wain',
#  'David Warren',
#  'David Wnendt',
#  'David Yarovesky',
#  'David Yates',
#  'David Zellner',
#  'David Zucker',
#  'Davis Guggenheim',
#  'Dax Shepard',
#  'Dean Cundey',
#  'Dean DeBlois',
#  'Dean Devlin',
#  'Dean Holland',
#  'Dean Israelite',
#  'Dean Parisot',
#  'Dean Semler',
#  'Dean White',
#  'Deane Taylor',
#  'Deb Hagan',
#  'Debbie Allen',
#  'Deborah Chow',
#  'Debra Granik',
#  'Declan Donnellan',
#  'Declan Lowney',
#  "Declan O'Brien",
#  'Dee Rees',
#  'Deepa Mehta',
#  'Delbert Mann',
#  'Delmer Daves',
#  'Demian Lichtenstein',
#  'Denis Villeneuve',
#  'Denise Di Novi',
#  'Deniz Gamze Ergüven',
#  'Dennie Gordon',
#  'Dennis Berry',
#  'Dennis Dugan',
#  'Dennis Gansel',
#  'Dennis Hopper',
#  'Dennis Iliadis',
#  'Dennis Lee',
#  'Dennis Smith',
#  'Denys Arcand',
#  'Denzel Washington',
#  'Deon Taylor',
#  'Deran Sarafian',
#  'Derek Cianfrance',
#  'Derek Lee',
#  'Derick Martini',
#  'Dermott Downs',
#  'Derrick Borte',
#  'Des McAnuff',
#  'Desiree Akhavan',
#  'Desmond Davis',
#  'Destin Daniel Cretton',
#  ...]

# %% [markdown]
# ## Obtaining  a list of movies which contain the word "love"

# %%
def love_movies(db_cursor):
    """return the list of all movies which contain the exact word "love"
    in their title, sorted in alphabetical order"""

    query = """
            SELECT title
            FROM movies
            WHERE UPPER(title) LIKE '% LOVE %'
            OR UPPER(title) LIKE 'LOVE %'
            OR UPPER(title) LIKE '% LOVE'
            OR UPPER(title) LIKE 'LOVE'
            OR UPPER(title) LIKE '% LOVE''%'
            OR UPPER(title) LIKE '% LOVE.'
            OR UPPER(title) LIKE 'LOVE,%'
            ORDER BY title
            """

    db_cursor.execute(query)
    rows = db_cursor.fetchall()

    print(f"""
    {type(rows) = }
    {len(rows) = }
    {[row.keys() for row in rows][0] = }
    """)

    return [row[row.keys()[0]] for row in rows]


love_movies(db_cursor=cursor)
# Out:
#     type(rows) = <class 'list'>
#     len(rows) = 77
#     [row.keys() for row in rows][0] = ['title']
# ['A Lot Like Love',
#  'A Love Song for Bobby Long',
#  'A Short Film About Love',
#  'Addicted to Love',
#  'All the Boys Love Mandy Lane',
#  'American Pie Presents: The Book of Love',
#  'Big Love',
#  "Can't Buy Me Love",
#  'Capitalism: A Love Story',
#  'Crazy, Stupid, Love.',
#  'Down with Love',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'Eat Pray Love',
#  'Endless Love',
#  'Everyone Says I Love You',
#  'Falling in Love',
#  'Feast of Love',
#  'For Love and Honor',
#  'For Love of the Game',
#  'For Love or Money',
#  'Found a Treasure Called Love',
#  'From Paris with Love',
#  'From Russia with Love',
#  'I Am Love',
#  'I Love Lucy',
#  'I Love Trouble',
#  'I Love You Phillip Morris',
#  'I Love You to Death',
#  'I Love You, Beth Cooper',
#  'I Love You, Man',
#  'I Think I Love My Wife',
#  'In the Mood for Love',
#  "Intolerance: Love's Struggle Throughout the Ages",
#  'Last Love',
#  'Love',
#  'Love',
#  'Love & Basketball',
#  'Love & Friendship',
#  'Love & Mercy',
#  'Love & Other Drugs',
#  'Love Aaj Kal',
#  'Love Actually',
#  'Love Exposure',
#  'Love Happens',
#  'Love Is All You Need',
#  'Love Is Strange',
#  'Love Likes Coincidences',
#  'Love Me If You Dare',
#  'Love Potion No. 9',
#  'Love Story',
#  'Love and Death',
#  'Love and Other Disasters',
#  'Love in the Afternoon',
#  'Love in the Time of Cholera',
#  'Love the Coopers',
#  'Love, Death & Robots',
#  'Love, Rosie',
#  'Love, Simon',
#  'Must Love Dogs',
#  'My Summer of Love',
#  'New York, I Love You',
#  'P.S. I Love You',
#  'Punch-Drunk Love',
#  'Sea of Love',
#  'Shakespeare in Love',
#  'Show Me Love',
#  'Stuck in Love.',
#  'The Consequences of Love',
#  'The Edge of Love',
#  'The Love Bug',
#  'The Love Guru',
#  'The Love Punch',
#  'The One I Love',
#  'To Rome with Love',
#  'To Sir, with Love',
#  "What's Love Got to Do with It",
#  'Wristcutters: A Love Story']

# %% [markdown]
# ## Obtaining  a list of directors which contain a given word in their name

# %%
def directors_named_like_count(db_cursor, name):
    """return the number of directors which contain a given word in their name"""

    query = """
                SELECT COUNT(name) AS name_count
                FROM directors
                WHERE name LIKE ?
                """

    db_cursor.execute(query, (f"%{name}%",))
    rows = db_cursor.fetchall()

    print(f"""
    {type(rows) = }
    {len(rows) = }
    {[row.keys() for row in rows][0] = }
    """)

    return f"{name}: {[row[row.keys()[0]] for row in rows][0]}"

directors_named_like_count(db_cursor=cursor, name="Paul")
# Out:
#     type(rows) = <class 'list'>
#     len(rows) = 1
#     [row.keys() for row in rows][0] = ['name_count']
# 'Paul: 51'

# %% [markdown]
# ## Obtaining  a list of dictionaries with movies  longer than a given duration

# %%
def movies_longer_than(db_cursor, minutes):
    """return a list dictionaries of movies which are longer than a given duration,
    sorted in the alphabetical order"""
    query = """
            SELECT title,  minutes
            FROM movies                       
            WHERE minutes >= ? 
            ORDER BY title     
            """

    # ['title', 'rating', 'vote_count', 'start_year', 'minutes', 'genres', 'imdb_id', 'id', 'director_id']

    db_cursor.execute(query, (f"{minutes}",))
    rows = db_cursor.fetchall()

    print(f"""
    {type(rows) = }
    {len(rows) = }
    {[row.keys() for row in rows][0] = }
    """)

    return [{"title": row["title"],
             "minutes": row["minutes"]} for row in rows]

movies_longer_than(db_cursor=cursor, minutes=500)
# Out:
#     type(rows) = <class 'list'>
#     len(rows) = 17
#     [row.keys() for row in rows][0] = ['title', 'minutes']
# [{'title': 'Band of Brothers', 'minutes': 594},
#  {'title': 'Cosmos', 'minutes': 557},
#  {'title': 'Dekalog', 'minutes': 572},
#  {'title': 'I, Claudius', 'minutes': 669},
#  {'title': 'Jackass', 'minutes': 535},
#  {'title': 'Neon Genesis Evangelion', 'minutes': 624},
#  {'title': 'Planet Earth', 'minutes': 538},
#  {'title': 'Roots', 'minutes': 588},
#  {'title': 'Taken', 'minutes': 877},
#  {'title': 'The Civil War', 'minutes': 680},
#  {'title': 'The Godfather Trilogy: 1901-1980', 'minutes': 583},
#  {'title': 'The Kingdom', 'minutes': 561},
#  {'title': 'The Night Of', 'minutes': 525},
#  {'title': 'The Pacific', 'minutes': 530},
#  {'title': 'The Staircase', 'minutes': 629},
#  {'title': 'The Vietnam War', 'minutes': 990},
#  {'title': 'The Young Pope', 'minutes': 546}]

# %% [markdown]
# ## Obtaining  a list of movies with their genres and director name

# %%
def detailed_movies(db_cursor):
    """return the list of movies with their genres and director name"""
    query = db_cursor.execute(
        """
        SELECT directors.name, movies.title, movies.genres FROM movies
        JOIN directors ON directors.id = movies.director_id
        ORDER BY name
        """
    )
    rows = query.fetchall()

    print(f"""
    {type(rows) = }
    {len(rows) = }
    {[row.keys() for row in rows][0] = }
    """)

    return [[row[key] for key in row.keys()] for row in rows]

detailed_movies(db_cursor=cursor)
# Out:
#     type(rows) = <class 'list'>
#     len(rows) = 9872
#     [row.keys() for row in rows][0] = ['name', 'title', 'genres']
# [['A.R. Murugadoss', 'Ghajini', 'Action,Drama,Mystery'],
#  ['A.R. Murugadoss', 'Ghajini', 'Action,Drama,Mystery'],
#  ['A.R. Murugadoss', 'Thuppakki', 'Action,Thriller'],
#  ['A.R. Murugadoss', 'Holiday', 'Action,Thriller'],
#  ['A.R. Murugadoss', 'Kaththi', 'Action,Drama'],
#  ['A.R. Murugadoss', 'Sarkar', 'Action,Drama'],
#  ['Aamir Khan', 'Like Stars on Earth', 'Drama,Family'],
#  ['Aanand L. Rai', 'Tanu Weds Manu', 'Comedy,Drama,Romance'],
#  ['Aanand L. Rai', 'Tanu Weds Manu Returns', 'Comedy,Drama,Romance'],
#  ['Aanand L. Rai', 'Raanjhanaa', 'Drama,Romance'],
#  ['Aanand L. Rai', 'Zero', 'Comedy,Drama,Romance'],
#  ['Aaron Hann', 'Circle', 'Drama,Horror,Mystery'],
#  ['Aaron Harvey', 'Catch .44', 'Action,Crime,Drama'],
#  ['Aaron Horvath', 'Teen Titans Go! To the Movies', 'Action,Animation,Comedy'],
#  ['Aaron Lipstadt', 'Medium', 'Crime,Drama,Fantasy'],
#  ['Aaron Moorhead', 'Resolution', 'Horror,Mystery,Thriller'],
#  ['Aaron Schneider', 'Get Low', 'Drama,Mystery'],
#  ['Aaron Seltzer', 'Date Movie', 'Comedy,Romance'],
#  ['Aaron Seltzer', 'Meet the Spartans', 'Comedy'],
#  ['Aaron Sorkin', "Molly's Game", 'Biography,Crime,Drama'],
#  ['Aaron Springer', 'Gravity Falls', 'Action,Adventure,Animation'],
#  ['Abbas Alibhai Burmawalla', 'Baadshah', 'Action,Comedy,Crime'],
#  ['Abbas Alibhai Burmawalla', 'Race', 'Action,Crime,Drama'],
#  ['Abbas Kiarostami', 'Close-Up', 'Biography,Crime,Drama'],
#  ['Abbas Kiarostami', 'Taste of Cherry', 'Drama'],
#  ['Abbas Kiarostami', 'Certified Copy', 'Drama,Romance'],
#  ['Abbas Tyrewala', 'Jaane Tu... Ya Jaane Na', 'Comedy,Drama,Romance'],
#  ['Abby Kohn', 'I Feel Pretty', 'Comedy,Romance'],
#  ['Abdellatif Kechiche', 'Blue Is the Warmest Color', 'Drama,Romance'],
#  ['Abderrahmane Sissako', 'Timbuktu', 'Drama,War'],
#  ['Abe Sylvia', 'Dirty Girl', 'Comedy,Drama'],
#  ['Abel Ferrara', 'King of New York', 'Crime,Thriller'],
#  ['Abel Ferrara', 'Bad Lieutenant', 'Crime,Drama,Thriller'],
#  ['Abel Ferrara', 'Body Snatchers', 'Horror,Sci-Fi'],
#  ['Abhinav Kashyap', 'Fearless', 'Action,Comedy'],
#  ['Abhinay Deo', 'Delhi Belly', 'Action,Comedy,Crime'],
#  ['Abhishek Chaubey', 'Udta Punjab', 'Action,Crime,Drama'],
#  ['Abhishek Kapoor', 'Rock On!!', 'Drama,Music'],
#  ['Abhishek Kapoor', 'Kai po che!', 'Drama,Sport'],
#  ['Abhishek Sharma', 'Parmanu: The Story of Pokhran', 'Action,Drama,History'],
#  ['Abhishek Varman', '2 States', 'Comedy,Drama,Romance'],
#  ['Abram Cox', 'Black Summer', 'Action,Drama,Horror'],
#  ['Adam Arkin', 'Justified', 'Action,Crime,Drama'],
#  ['Adam Arkin', 'The Blacklist', 'Crime,Drama,Mystery'],
#  ['Adam Bernstein', "Cat's in the Bag...", 'Crime,Drama,Thriller'],
#  ['Adam Bernstein', "...And the Bag's in the River", 'Crime,Drama,Thriller'],
#  ['Adam Bernstein', 'Mandala', 'Crime,Drama,Thriller'],
#  ['Adam Bernstein', 'ABQ', 'Crime,Drama,Thriller'],
#  ['Adam Bernstein', 'Caballo sin Nombre', 'Crime,Drama,Thriller'],
#  ['Adam Bernstein', 'Half Measures', 'Crime,Drama,Thriller'],
#  ['Adam Bernstein', 'Box Cutter', 'Crime,Drama,Thriller'],
#  ['Adam Bernstein', 'Hazard Pay', 'Crime,Drama,Thriller'],
#  ['Adam Bernstein', "The Crocodile's Dilemma", 'Crime,Drama,Thriller'],
#  ['Adam Bernstein', 'Five-O', 'Crime,Drama'],
#  ['Adam Brooks', 'Definitely, Maybe', 'Comedy,Drama,Romance'],
#  ['Adam Davidson', 'Entourage', 'Comedy,Drama'],
#  ['Adam Davidson', 'Shark', 'Crime,Drama,Mystery'],
#  ['Adam Elliot', 'Mary and Max', 'Animation,Comedy,Drama'],
#  ['Adam Green', 'Hatchet', 'Comedy,Horror,Thriller'],
#  ['Adam Green', 'Hatchet II', 'Action,Comedy,Horror'],
#  ['Adam Green', 'Frozen', 'Drama,Thriller'],
#  ['Adam Jay Epstein', 'Extreme Movie', 'Comedy'],
#  ['Adam Kassen', 'Puncture', 'Biography,Drama'],
#  ['Adam MacDonald', 'Backcountry', 'Drama,Horror,Thriller'],
#  ['Adam Marcus',
#   'Jason Goes to Hell: The Final Friday',
#   'Fantasy,Horror,Thriller'],
#  ['Adam McKay', 'Anchorman: The Legend of Ron Burgundy', 'Comedy'],
#  ['Adam McKay', 'Talladega Nights: The Ballad of Ricky Bobby', 'Comedy,Sport'],
#  ['Adam McKay', 'Step Brothers', 'Comedy'],
#  ['Adam McKay', 'Anchorman 2: The Legend Continues', 'Comedy'],
#  ['Adam McKay', 'The Other Guys', 'Action,Comedy,Crime'],
#  ['Adam McKay', 'The Big Short', 'Biography,Comedy,Drama'],
#  ['Adam McKay', 'Vice', 'Biography,Comedy,Drama'],
#  ['Adam Paloian', 'SpongeBob SquarePants', 'Animation,Comedy,Family'],
#  ['Adam Randall', 'iBoy', 'Action,Crime,Sci-Fi'],
#  ['Adam Rifkin', 'The Chase', 'Action,Adventure,Comedy'],
#  ['Adam Rifkin', 'Detroit Rock City', 'Comedy,Music'],
#  ['Adam Robitel', 'The Taking of Deborah Logan', 'Horror,Mystery,Thriller'],
#  ['Adam Robitel', 'Insidious: The Last Key', 'Horror,Mystery,Thriller'],
#  ['Adam Robitel', 'Escape Room', 'Action,Adventure,Horror'],
#  ['Adam Schindler', 'Intruders', 'Drama,Horror,Thriller'],
#  ['Adam Shankman', 'The Wedding Planner', 'Comedy,Romance'],
#  ['Adam Shankman', 'A Walk to Remember', 'Drama,Romance'],
#  ['Adam Shankman', 'Bringing Down the House', 'Comedy'],
#  ['Adam Shankman', 'The Pacifier', 'Action,Comedy,Drama'],
#  ['Adam Shankman', 'Hairspray', 'Comedy,Drama,Musical'],
#  ['Adam Shankman', 'Cheaper by the Dozen 2', 'Adventure,Comedy,Family'],
#  ['Adam Shankman', 'Bedtime Stories', 'Comedy,Family,Fantasy'],
#  ['Adam Shankman', 'Rock of Ages', 'Comedy,Drama,Musical'],
#  ['Adam Shankman', 'What Men Want', 'Comedy,Fantasy,Romance'],
#  ['Adam Weissman', 'Zoey 101', 'Comedy,Drama,Family'],
#  ['Adam Wingard', 'Death Note', 'Adventure,Crime,Drama'],
#  ['Adam Wingard', 'Blair Witch', 'Horror,Mystery,Thriller'],
#  ['Adam Wingard', "You're Next", 'Horror,Mystery,Thriller'],
#  ['Adam Wingard', 'The Guest', 'Action,Comedy,Crime'],
#  ['Adam Wingard', 'Outcast', 'Drama,Horror'],
#  ['Adesh Prasad', 'Tumbbad', 'Drama,Fantasy,Horror'],
#  ['Aditya Chopra', 'Dilwale Dulhania Le Jayenge', 'Drama,Romance'],
#  ['Aditya Chopra', 'Mohabbatein', 'Drama,Musical,Romance'],
#  ['Aditya Chopra', 'Rab Ne Bana Di Jodi', 'Comedy,Drama,Music'],
#  ['Aditya Datt', 'Table No. 21', 'Adventure,Thriller'],
#  ['Aditya Dhar', 'Uri: The Surgical Strike', 'Action,Drama,War'],
#  ['Adrian Grunberg', 'Rambo: Last Blood', 'Action,Adventure,Thriller'],
#  ['Adrian Grunberg', 'Get the Gringo', 'Action,Crime,Drama'],
#  ['Adrian Lyne', 'Flashdance', 'Drama,Music,Romance'],
#  ['Adrian Lyne', '9½ Weeks', 'Drama,Romance'],
#  ['Adrian Lyne', 'Fatal Attraction', 'Drama,Thriller'],
#  ['Adrian Lyne', "Jacob's Ladder", 'Drama,Horror,Mystery'],
#  ['Adrian Lyne', 'Indecent Proposal', 'Drama,Romance'],
#  ['Adrian Lyne', 'Lolita', 'Drama,Romance'],
#  ['Adrian Lyne', 'Unfaithful', 'Drama,Romance,Thriller'],
#  ['Adrian Molina', 'Coco', 'Adventure,Animation,Family'],
#  ['Adrian Shergold', 'Persuasion', 'Drama,Romance'],
#  ['Adrienne Shelly', 'Waitress', 'Comedy,Drama,Romance'],
#  ['Advait Chandan', 'Secret Superstar', 'Drama,Music'],
#  ['Afonso Poyart', 'Solace', 'Crime,Drama,Mystery'],
#  ['Agnieszka Holland', 'Europa Europa', 'Drama,History,War'],
#  ['Agnieszka Holland', 'The Secret Garden', 'Drama,Family,Fantasy'],
#  ['Agnieszka Holland', 'Total Eclipse', 'Biography,Drama,Romance'],
#  ['Agnieszka Holland', 'Copying Beethoven', 'Biography,Drama,Music'],
#  ['Agnieszka Wojtowicz-Vosloo', 'After.Life', 'Drama,Mystery,Thriller'],
#  ['Agnès Varda', 'Cleo from 5 to 7', 'Comedy,Drama,Music'],
#  ['Agustín Díaz Yanes', 'Alatriste', 'Adventure,Drama,History'],
#  ['Aharon Keshales', 'Big Bad Wolves', 'Drama,Horror,Thriller'],
#  ['Aisling Walsh', 'Maudie', 'Biography,Drama,Romance'],
#  ['Aki Kaurismäki', 'The Man Without a Past', 'Comedy,Drama,Romance'],
#  ['Aki Kaurismäki', 'Le Havre', 'Comedy,Drama'],
#  ['Akira Kurosawa', 'Stray Dog', 'Crime,Drama,Film-Noir'],
#  ['Akira Kurosawa', 'Rashomon', 'Crime,Drama,Mystery'],
#  ['Akira Kurosawa', 'Ikiru', 'Drama'],
#  ['Akira Kurosawa', 'Seven Samurai', 'Adventure,Drama'],
#  ['Akira Kurosawa', 'Throne of Blood', 'Drama,History'],
#  ['Akira Kurosawa', 'The Hidden Fortress', 'Adventure,Drama'],
#  ['Akira Kurosawa', 'Yojimbo', 'Action,Comedy,Crime'],
#  ['Akira Kurosawa', 'Sanjuro', 'Action,Crime,Drama'],
#  ['Akira Kurosawa', 'High and Low', 'Crime,Drama,Mystery'],
#  ['Akira Kurosawa', 'Red Beard', 'Drama'],
#  ['Akira Kurosawa', 'Dersu Uzala', 'Adventure,Biography,Drama'],
#  ['Akira Kurosawa', 'Kagemusha', 'Drama,History,War'],
#  ['Akira Kurosawa', 'Ran', 'Action,Drama'],
#  ['Akira Kurosawa', 'Dreams', 'Drama,Fantasy'],
#  ['Akitsugu Hisagi', 'One Punch Man', 'Action,Adventure,Animation'],
#  ['Akiva Goldsman', "Winter's Tale", 'Drama,Fantasy,Mystery'],
#  ['Akiva Schaffer', 'Hot Rod', 'Comedy,Sport'],
#  ['Akiva Schaffer', 'The Watch', 'Action,Comedy,Horror'],
#  ['Akiva Schaffer', 'Popstar: Never Stop Never Stopping', 'Comedy,Music'],
#  ['Alain Chabat',
#   'Asterix and Obelix Meet Cleopatra',
#   'Adventure,Comedy,Family'],
#  ['Alain Chabat', 'RRRrrrr!!!', 'Adventure,Comedy,Crime'],
#  ['Alain Desrochers', 'Security', 'Action,Crime,Thriller'],
#  ['Alain Guiraudie', 'Stranger by the Lake', 'Drama,Romance,Thriller'],
#  ['Alain Resnais', 'Night and Fog', 'Documentary,History,Short'],
#  ['Alain Resnais', 'Hiroshima Mon Amour', 'Drama,Romance'],
#  ['Alain Resnais', 'Last Year at Marienbad', 'Drama,Mystery'],
#  ['Alan Ball', 'Six Feet Under', 'Comedy,Drama'],
#  ['Alan Ball', 'Towelhead', 'Drama'],
#  ['Alan Barillaro', 'Piper', 'Animation,Family,Short'],
#  ['Alan Carter', 'The Voice', 'Game-Show,Music,Reality-TV'],
#  ['Alan Cohn', 'Dead Man on Campus', 'Comedy'],
#  ['Alan Grint', 'The Adventures of Sherlock Holmes', 'Crime,Drama,Mystery'],
#  ['Alan J. Levi', 'NCIS', 'Action,Crime,Drama'],
#  ['Alan J. Pakula', 'Klute', 'Crime,Mystery,Thriller'],
#  ['Alan J. Pakula', 'The Parallax View', 'Drama,Thriller'],
#  ['Alan J. Pakula', "All the President's Men", 'Biography,Drama,History'],
#  ['Alan J. Pakula', "Sophie's Choice", 'Drama,Romance'],
#  ['Alan J. Pakula', 'Presumed Innocent', 'Mystery,Thriller'],
#  ['Alan J. Pakula', 'The Pelican Brief', 'Crime,Drama,Mystery'],
#  ['Alan J. Pakula', "The Devil's Own", 'Action,Crime,Drama'],
#  ['Alan Mak', 'Infernal Affairs', 'Crime,Drama,Mystery'],
#  ['Alan Metter', 'Back to School', 'Comedy,Romance,Sport'],
#  ['Alan Metter', 'Police Academy: Mission to Moscow', 'Comedy,Crime'],
#  ['Alan Myerson', 'Police Academy 5: Assignment: Miami Beach', 'Comedy,Crime'],
#  ['Alan Myerson', 'Boy Meets World', 'Comedy,Drama,Family'],
#  ['Alan Parker', 'Bugsy Malone', 'Comedy,Crime,Family'],
#  ['Alan Parker', 'Midnight Express', 'Biography,Crime,Drama'],
#  ['Alan Parker', 'Fame', 'Drama,Music,Musical'],
#  ['Alan Parker', 'Pink Floyd: The Wall', 'Animation,Drama,Fantasy'],
#  ['Alan Parker', 'Birdy', 'Drama,War'],
#  ['Alan Parker', 'Angel Heart', 'Horror,Mystery,Thriller'],
#  ['Alan Parker', 'Mississippi Burning', 'Crime,Drama,History'],
#  ['Alan Parker', 'The Commitments', 'Comedy,Drama,Music'],
#  ['Alan Parker', 'The Road to Wellville', 'Comedy,Drama'],
#  ['Alan Parker', 'Evita', 'Biography,Drama,History'],
#  ['Alan Parker', "Angela's Ashes", 'Drama'],
#  ['Alan Parker', 'The Life of David Gale', 'Crime,Drama,Thriller'],
#  ['Alan Poul', 'The Back-up Plan', 'Comedy,Romance'],
#  ['Alan Poul', 'The Newsroom', 'Drama'],
#  ['Alan Rafkin', 'The Andy Griffith Show', 'Comedy,Family'],
#  ['Alan Rickman', 'A Little Chaos', 'Drama,Romance'],
#  ['Alan Shapiro', 'The Crush', 'Drama,Thriller'],
#  ['Alan Taylor', 'Deadwood', 'Crime,Drama,History'],
#  ['Alan Taylor', 'Terminator Genisys', 'Action,Adventure,Sci-Fi'],
#  ['Alan Taylor', 'Fire and Blood', 'Action,Adventure,Drama'],
#  ['Alan Taylor', 'Baelor', 'Action,Adventure,Drama'],
#  ['Alan Taylor', 'The North Remembers', 'Action,Adventure,Drama'],
#  ['Alan Taylor', 'Thor: The Dark World', 'Action,Adventure,Fantasy'],
#  ['Alan Taylor', 'The Night Lands', 'Action,Adventure,Drama'],
#  ['Alan Taylor', 'The Prince of Winterfell', 'Action,Adventure,Drama'],
#  ['Alan Taylor', 'Valar Morghulis', 'Action,Adventure,Drama'],
#  ['Alan Taylor', 'Beyond the Wall', 'Action,Adventure,Drama'],
#  ['Alan Yang', 'Master of None', 'Comedy'],
#  ['Alan Yang', 'The Good Place', 'Comedy,Drama,Fantasy'],
#  ['Alastair Fothergill', 'The Blue Planet', 'Documentary'],
#  ['Alastair Fothergill', 'Earth', 'Documentary'],
#  ['Alastair Fothergill', 'Planet Earth', 'Documentary'],
#  ['Albert Brooks', 'Defending Your Life', 'Comedy,Drama,Fantasy'],
#  ['Albert Brooks', 'The Muse', 'Comedy'],
#  ['Albert Calleros', 'The Cleveland Show', 'Adventure,Animation,Comedy'],
#  ['Albert Hughes', 'Menace II Society', 'Crime,Drama,Thriller'],
#  ['Albert Hughes', 'Dead Presidents', 'Action,Crime,Drama'],
#  ['Albert Hughes', 'From Hell', 'Horror,Mystery,Thriller'],
#  ['Albert Hughes', 'The Book of Eli', 'Action,Adventure,Drama'],
#  ['Albert Hughes', 'Alpha', 'Adventure,Drama,Family'],
#  ['Albert Lamorisse', 'The Red Balloon', 'Comedy,Drama,Family'],
#  ['Albert Lewin', 'The Picture of Dorian Gray', 'Drama,Fantasy,Horror'],
#  ['Albert Magnoli', 'Purple Rain', 'Drama,Music,Musical'],
#  ['Albert Pyun', 'Cyborg', 'Action,Sci-Fi,Thriller'],
#  ['Albert Pyun', 'Captain America', 'Action,Adventure,Sci-Fi'],
#  ['Alberto Mielgo', 'The Witness', 'Animation,Comedy,Fantasy'],
#  ['Alberto Rodríguez', 'Marshland', 'Crime,Horror,Mystery'],
#  ['Alejandro Agresti', 'The Lake House', 'Drama,Fantasy,Romance'],
#  ['Alejandro Amenábar', 'Thesis', 'Mystery,Thriller'],
#  ['Alejandro Amenábar', 'Open Your Eyes', 'Drama,Mystery,Sci-Fi'],
#  ['Alejandro Amenábar', 'The Others', 'Horror,Mystery,Thriller'],
#  ['Alejandro Amenábar', 'The Sea Inside', 'Biography,Drama'],
#  ['Alejandro Amenábar', 'Agora', 'Adventure,Biography,Drama'],
#  ['Alejandro Amenábar', 'Regression', 'Crime,Horror,Mystery'],
#  ['Alejandro G. Iñárritu', 'Amores Perros', 'Drama,Thriller'],
#  ['Alejandro G. Iñárritu', '21 Grams', 'Crime,Drama,Thriller'],
#  ['Alejandro G. Iñárritu', 'Babel', 'Drama'],
#  ['Alejandro G. Iñárritu', 'Biutiful', 'Drama,Romance'],
#  ['Alejandro G. Iñárritu', 'The Revenant', 'Action,Adventure,Biography'],
#  ['Alejandro G. Iñárritu',
#   'Birdman or (The Unexpected Virtue of Ignorance)',
#   'Comedy,Drama'],
#  ['Alejandro Jodorowsky', 'El Topo', 'Drama,Western'],
#  ['Alejandro Jodorowsky', 'The Holy Mountain', 'Adventure,Drama,Fantasy'],
#  ['Alejandro Jodorowsky', 'Santa Sangre', 'Drama,Fantasy,Horror'],
#  ['Alejandro Monteverde', 'Bella', 'Drama,Romance'],
#  ['Alejandro Monteverde', 'Little Boy', 'Drama,History,War'],
#  ['Alek Keshishian', 'With Honors', 'Comedy,Drama'],
#  ['Alek Keshishian', 'Love and Other Disasters', 'Comedy,Drama,Romance'],
#  ['Aleksander Bach', 'Hitman: Agent 47', 'Action,Crime,Thriller'],
#  ['Aleksandr Sokurov', 'Russian Ark', 'Drama,Fantasy,History'],
#  ['Aleksey Balabanov', 'Brother', 'Crime,Drama,Romance'],
#  ['Aleksey Balabanov', 'Brother 2', 'Action,Crime,Thriller'],
#  ['Aleksey Pimanov', 'Crimea', 'Action,Drama'],
#  ['Alessandro Carloni', 'Kung Fu Panda 3', 'Action,Adventure,Animation'],
#  ['Alex Brewer', 'The Trust', 'Comedy,Crime,Drama'],
#  ['Alex Cox', 'Repo Man', 'Comedy,Crime,Sci-Fi'],
#  ['Alex Cox', 'Sid and Nancy', 'Biography,Drama,Music'],
#  ['Alex Garland', 'Ex Machina', 'Drama,Mystery,Sci-Fi'],
#  ['Alex Garland', 'Annihilation', 'Adventure,Drama,Horror'],
#  ['Alex Gibney', 'Taxi to the Dark Side', 'Crime,Documentary,News'],
#  ['Alex Gibney',
#   'Enron: The Smartest Guys in the Room',
#   'Biography,Documentary,History'],
#  ['Alex Gibney',
#   'Going Clear: Scientology & the Prison of Belief',
#   'Documentary'],
#  ['Alex Graves', 'Kissed by Fire', 'Action,Adventure,Drama'],
#  ['Alex Graves', 'And Now His Watch Is Ended', 'Action,Adventure,Drama'],
#  ['Alex Graves', 'The Lion and the Rose', 'Action,Adventure,Drama'],
#  ['Alex Graves', 'Breaker of Chains', 'Action,Adventure,Drama'],
#  ['Alex Graves', 'The Mountain and the Viper', 'Action,Adventure,Drama'],
#  ['Alex Graves', 'The Children', 'Action,Adventure,Drama'],
#  ['Alex Gregory', 'A Good Old Fashioned Orgy', 'Comedy,Romance'],
#  ['Alex Hall', 'The Deuce', 'Drama'],
#  ['Alex Hardcastle', 'Suburgatory', 'Comedy'],
#  ['Alex Hardcastle',
#   "A Young Doctor's Notebook & Other Stories",
#   'Comedy,Drama'],
#  ['Alex Hardcastle', 'The Mindy Project', 'Comedy'],
#  ['Alex Kendrick', 'Facing the Giants', 'Drama,Fantasy,Sport'],
#  ['Alex Kendrick', 'Fireproof', 'Drama,Fantasy,Romance'],
#  ['Alex Kendrick', 'Courageous', 'Drama,Fantasy'],
#  ['Alex Kendrick', 'War Room', 'Drama'],
#  ['Alex Kurtzman', 'People Like Us', 'Comedy,Drama'],
#  ['Alex Kurtzman', 'The Mummy', 'Action,Adventure,Fantasy'],
#  ['Alex Lehmann', 'Blue Jay', 'Drama,Romance'],
#  ['Alex Proyas', 'The Crow', 'Action,Drama,Fantasy'],
#  ['Alex Proyas', 'Dark City', 'Mystery,Sci-Fi,Thriller'],
#  ['Alex Proyas', 'I, Robot', 'Action,Crime,Drama'],
#  ['Alex Proyas', 'Knowing', 'Action,Drama,Mystery'],
#  ['Alex Proyas', 'Gods of Egypt', 'Action,Adventure,Fantasy'],
#  ['Alex Richanbach', 'Ibiza', 'Comedy,Romance'],
#  ['Alex Winckler', 'My Mad Fat Diary', 'Comedy,Drama,Romance'],
#  ['Alex Zakrzewski', 'Cold Case', 'Crime,Drama,Mystery'],
#  ['Alex Zakrzewski', 'Body of Proof', 'Crime,Drama'],
#  ['Alex Zamm', 'A Christmas Prince', 'Comedy,Romance'],
#  ['Alex van Warmerdam', 'Borgman', 'Drama,Horror,Mystery'],
#  ['Alexander Mackendrick', 'The Ladykillers', 'Comedy,Crime'],
#  ['Alexander Mackendrick', 'Sweet Smell of Success', 'Drama,Film-Noir'],
#  ['Alexander Payne', 'Election', 'Comedy,Drama,Romance'],
#  ['Alexander Payne', 'About Schmidt', 'Comedy,Drama'],
#  ['Alexander Payne', 'Sideways', 'Comedy,Drama,Romance'],
#  ['Alexander Payne', 'The Descendants', 'Comedy,Drama'],
#  ['Alexander Payne', 'Downsizing', 'Drama,Sci-Fi'],
#  ['Alexander Payne', 'Nebraska', 'Adventure,Comedy,Drama'],
#  ['Alexander Witt', 'Resident Evil: Apocalypse', 'Action,Horror,Sci-Fi'],
#  ['Alexandre Aja', 'High Tension', 'Horror'],
#  ['Alexandre Aja', 'The Hills Have Eyes', 'Horror,Thriller'],
#  ['Alexandre Aja', 'Piranha 3D', 'Comedy,Horror'],
#  ['Alexandre Aja', 'Mirrors', 'Horror,Mystery'],
#  ['Alexandre Aja', 'Horns', 'Crime,Drama,Fantasy'],
#  ['Alexandre Aja', 'The 9th Life of Louis Drax', 'Mystery,Thriller'],
#  ['Alexandre Aja', 'Crawl', 'Action,Drama,Horror'],
#  ['Alexandre Amancio',
#   "Assassin's Creed: Revelations",
#   'Action,Adventure,History'],
#  ['Alexandre Avancini', 'Nothing to Lose', 'Biography,Drama'],
#  ['Alexandre Bustillo', 'Leatherface', 'Crime,Horror,Thriller'],
#  ['Alexandros Avranas', 'Dark Crimes', 'Crime,Drama,Thriller'],
#  ['Alfonso Arau', 'Like Water for Chocolate', 'Drama,Romance'],
#  ['Alfonso Arau', 'A Walk in the Clouds', 'Drama,Romance'],
#  ['Alfonso Cuarón', 'A Little Princess', 'Drama,Family,Fantasy'],
#  ['Alfonso Cuarón', 'Great Expectations', 'Drama,Romance'],
#  ['Alfonso Cuarón', 'Children of Men', 'Drama,Sci-Fi,Thriller'],
#  ['Alfonso Cuarón', 'Y Tu Mamá También', 'Drama'],
#  ['Alfonso Cuarón',
#   'Harry Potter and the Prisoner of Azkaban',
#   'Adventure,Family,Fantasy'],
#  ['Alfonso Cuarón', 'Gravity', 'Drama,Sci-Fi,Thriller'],
#  ['Alfonso Cuarón', 'Roma', 'Drama'],
#  ['Alfonso Gomez-Rejon',
#   'The Town That Dreaded Sundown',
#   'Horror,Mystery,Thriller'],
#  ['Alfonso Gomez-Rejon',
#   'Me and Earl and the Dying Girl',
#   'Comedy,Drama,Romance'],
#  ['Alfonso Ribeiro', 'The Fresh Prince of Bel-Air', 'Comedy'],
#  ['Alfred Gimeno', 'Animaniacs', 'Animation,Comedy,Family'],
#  ['Alfred Hitchcock', 'The Man Who Knew Too Much', 'Crime,Mystery,Thriller'],
#  ['Alfred Hitchcock', 'The 39 Steps', 'Film-Noir,Mystery,Thriller'],
#  ['Alfred Hitchcock', 'Sabotage', 'Crime,Thriller'],
#  ['Alfred Hitchcock', 'The Lady Vanishes', 'Film-Noir,Mystery,Thriller'],
#  ['Alfred Hitchcock', 'Foreign Correspondent', 'Action,Romance,Thriller'],
#  ['Alfred Hitchcock', 'Rebecca', 'Drama,Mystery,Romance'],
#  ['Alfred Hitchcock', 'Suspicion', 'Mystery,Thriller'],
#  ['Alfred Hitchcock', 'Saboteur', 'Thriller,War'],
#  ['Alfred Hitchcock', 'Shadow of a Doubt', 'Thriller'],
#  ['Alfred Hitchcock', 'Lifeboat', 'Drama,War'],
#  ['Alfred Hitchcock', 'Spellbound', 'Film-Noir,Mystery,Romance'],
#  ['Alfred Hitchcock', 'Notorious', 'Drama,Film-Noir,Romance'],
#  ['Alfred Hitchcock', 'Rope', 'Crime,Drama,Mystery'],
#  ['Alfred Hitchcock', 'Stage Fright', 'Film-Noir,Thriller'],
#  ['Alfred Hitchcock', 'Strangers on a Train', 'Crime,Film-Noir,Thriller'],
#  ['Alfred Hitchcock', 'I Confess', 'Crime,Drama,Thriller'],
#  ['Alfred Hitchcock', 'Dial M for Murder', 'Crime,Thriller'],
#  ['Alfred Hitchcock', 'Rear Window', 'Mystery,Thriller'],
#  ['Alfred Hitchcock', 'To Catch a Thief', 'Mystery,Romance,Thriller'],
#  ['Alfred Hitchcock', 'The Trouble with Harry', 'Comedy,Mystery'],
#  ['Alfred Hitchcock', 'The Man Who Knew Too Much', 'Drama,Thriller'],
#  ['Alfred Hitchcock', 'The Wrong Man', 'Drama,Film-Noir'],
#  ['Alfred Hitchcock', 'Vertigo', 'Mystery,Romance,Thriller'],
#  ['Alfred Hitchcock', 'North by Northwest', 'Adventure,Mystery,Thriller'],
#  ['Alfred Hitchcock', 'Psycho', 'Horror,Mystery,Thriller'],
#  ['Alfred Hitchcock', 'The Birds', 'Drama,Horror,Mystery'],
#  ['Alfred Hitchcock', 'Marnie', 'Crime,Drama,Mystery'],
#  ['Alfred Hitchcock', 'Torn Curtain', 'Thriller'],
#  ['Alfred Hitchcock', 'Topaz', 'Drama,Thriller'],
#  ['Alfred Hitchcock', 'Frenzy', 'Thriller'],
#  ['Alfred Hitchcock', 'Family Plot', 'Comedy,Crime,Drama'],
#  ['Ali Abbas Zafar', 'Gunday', 'Action,Drama,Romance'],
#  ['Ali Abbas Zafar', 'Sultan', 'Action,Drama,Sport'],
#  ['Ali Abbas Zafar', 'Tiger Zinda Hai', 'Action,Adventure,Thriller'],
#  ['Ali Abbas Zafar', 'Bharat', 'Action,Drama'],
#  ['Ali Abbasi', 'Border', 'Crime,Drama,Fantasy'],
#  ['Ali Atay', 'Ölümlü Dünya', 'Action,Comedy'],
#  ['Ali Taner Baltaci', 'The Magician', 'Comedy,Drama'],
#  ['Alice Dallow', 'MythBusters', 'Documentary,Mystery,Reality-TV'],
#  ['Alice Troughton', 'In the Flesh', 'Drama,Horror'],
#  ['Alik Sakharov', 'What Is Dead May Never Die', 'Action,Adventure,Drama'],
#  ['Alik Sakharov', 'The Climb', 'Action,Adventure,Drama'],
#  ['Alik Sakharov', 'Mockingbird', 'Action,Adventure,Drama'],
#  ['Alik Sakharov', 'The Laws of Gods and Men', 'Action,Adventure,Drama'],
#  ['Alison Maclean', 'Carnivàle', 'Drama,Fantasy,Mystery'],
#  ['Alister Grierson', 'Sanctum', 'Adventure,Drama,Thriller'],
#  ['Allan A. Goldstein', '2001: A Space Travesty', 'Comedy,Sci-Fi'],
#  ['Allan Arkush', 'Caddyshack II', 'Comedy,Sport'],
#  ['Allan Arkush', 'A Series of Unfortunate Events', 'Adventure,Comedy,Drama'],
#  ['Allan Cubitt', 'The Fall', 'Crime,Drama,Thriller'],
#  ['Allan Kartun', 'Conan', 'Comedy,Music,Talk-Show'],
#  ['Allan Kroeker', 'Gossip Girl', 'Drama,Romance'],
#  ['Allan Moyle', 'Pump Up the Volume', 'Comedy,Drama,Music'],
#  ['Allan Moyle', 'Empire Records', 'Comedy,Drama,Music'],
#  ['Allen Coulter', 'Hollywoodland', 'Biography,Crime,Drama'],
#  ['Allen Coulter', 'Remember Me', 'Drama,Romance'],
#  ['Allen Hughes', 'Broken City', 'Crime,Drama,Thriller'],
#  ['Allison Anders', 'Four Rooms', 'Comedy'],
#  ['Allison Burnett', 'Ask Me Anything', 'Drama'],
#  ['Allison Liddi-Brown', 'Princess Protection Program', 'Comedy,Drama,Family'],
#  ['Allison Liddi-Brown', 'The Good Doctor', 'Drama'],
#  ['Alper Caglar', 'The Mountain', 'Adventure,Drama,Thriller'],
#  ['Alper Caglar', 'The Mountain II', 'Action,Drama,War'],
#  ['Alphonse Puthren', 'Premam', 'Comedy,Drama,Romance'],
#  ['Alrick Riley', 'Spooks', 'Action,Crime,Drama'],
#  ['Alrick Riley', 'The Walking Dead', 'Drama,Horror,Thriller'],
#  ['Amar Kaushik', 'Stree', 'Comedy,Horror'],
#  ['Ami Canaan Mann', 'Texas Killing Fields', 'Crime,Drama,History'],
#  ['Ami Canaan Mann', 'Cloak & Dagger', 'Action,Adventure,Drama'],
#  ['Amit Golani', 'TVF Pitchers', 'Comedy,Drama'],
#  ['Amit Masurkar', 'Newton', 'Drama'],
#  ['Amit Ravindernath Sharma', 'Badhaai Ho', 'Comedy,Drama'],
#  ['Amitabh Reza Chowdhury', 'Aynabaji', 'Crime,Mystery,Thriller'],
#  ['Amma Asante', 'Belle', 'Biography,Drama,Romance'],
#  ['Amma Asante', 'A United Kingdom', 'Biography,Drama,Romance'],
#  ['Amol Palekar', 'Paheli', 'Drama,Fantasy,Romance'],
#  ['Amy Heckerling', 'Fast Times at Ridgemont High', 'Comedy,Drama'],
#  ['Amy Heckerling', 'Johnny Dangerously', 'Comedy,Crime'],
#  ['Amy Heckerling',
#   "National Lampoon's European Vacation",
#   'Adventure,Comedy'],
#  ['Amy Heckerling', "Look Who's Talking", 'Comedy'],
#  ['Amy Heckerling', "Look Who's Talking Too", 'Comedy,Family,Romance'],
#  ['Amy Heckerling', 'Clueless', 'Comedy,Romance'],
#  ['Amy Heckerling', 'Loser', 'Comedy,Romance'],
#  ['Amy Heckerling', 'I Could Never Be Your Woman', 'Comedy,Drama,Romance'],
#  ['Amy Heckerling', 'The Carrie Diaries', 'Comedy,Romance'],
#  ['Amy Hennig', "Uncharted: Drake's Fortune", 'Action,Adventure,Fantasy'],
#  ['Amy Hennig', 'Uncharted 2: Among Thieves', 'Action,Adventure,Fantasy'],
#  ['Amy Hudson',
#   'The Adventures of Jimmy Neutron: Boy Genius',
#   'Adventure,Animation,Comedy'],
#  ['Amy Poehler', 'Wine Country', 'Comedy'],
#  ['Amy Sherman-Palladino',
#   'Gilmore Girls: A Year in the Life',
#   'Comedy,Drama'],
#  ['Amy Winfrey', 'BoJack Horseman', 'Animation,Comedy,Drama'],
#  ['Amyn Kaderali', 'Private Practice', 'Comedy,Drama,Romance'],
#  ['Ana Lily Amirpour', 'A Girl Walks Home Alone at Night', 'Drama,Horror'],
#  ['Ana Lily Amirpour', 'The Bad Batch', 'Drama,Horror,Romance'],
#  ['Anand Tucker', 'Shopgirl', 'Drama,Romance'],
#  ['Anand Tucker', 'Leap Year', 'Comedy,Romance'],
#  ['Anders Engström', 'Taboo', 'Drama,Mystery,Thriller'],
#  ['Anders Thomas Jensen', 'Flickering Lights', 'Action,Comedy,Crime'],
#  ['Anders Thomas Jensen', 'The Green Butchers', 'Comedy,Drama'],
#  ['Anders Thomas Jensen', "Adam's Apples", 'Comedy,Crime,Drama'],
#  ['Anders Walter', 'I Kill Giants', 'Drama,Fantasy,Thriller'],
#  ['Andrea Arnold', 'Red Road', 'Drama,Mystery,Thriller'],
#  ['Andrea Arnold', 'Fish Tank', 'Drama'],
#  ['Andrea Arnold', 'American Honey', 'Adventure,Drama,Romance'],
#  ['Andrea Di Stefano', 'Escobar: Paradise Lost', 'Crime,Drama,History'],
#  ['Andreas Prochaska', 'The Dark Valley', 'Action,Drama,Western'],
#  ['Andrei Tarkovsky', "Ivan's Childhood", 'Drama,War'],
#  ['Andrei Tarkovsky', 'Andrei Rublev', 'Biography,Drama,History'],
#  ['Andrei Tarkovsky', 'Solaris', 'Drama,Mystery,Sci-Fi'],
#  ['Andrei Tarkovsky', 'The Mirror', 'Biography,Drama'],
#  ['Andrei Tarkovsky', 'Stalker', 'Drama,Sci-Fi'],
#  ['Andrei Tarkovsky', 'Nostalgia', 'Drama'],
#  ['Andrei Tarkovsky', 'The Sacrifice', 'Drama'],
#  ['Andrew Adamson', 'Shrek', 'Adventure,Animation,Comedy'],
#  ['Andrew Adamson', 'Shrek 2', 'Adventure,Animation,Comedy'],
#  ['Andrew Adamson',
#   'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'Adventure,Family,Fantasy'],
#  ['Andrew Adamson',
#   'The Chronicles of Narnia: Prince Caspian',
#   'Action,Adventure,Family'],
#  ['Andrew Bergman', 'The Freshman', 'Comedy,Crime'],
#  ['Andrew Bergman', 'Honeymoon in Vegas', 'Comedy,Romance,Thriller'],
#  ['Andrew Bergman', 'It Could Happen to You', 'Comedy,Drama,Romance'],
#  ['Andrew Bergman', 'Striptease', 'Comedy,Crime,Drama'],
#  ['Andrew Bernstein', 'Pan Am', 'Drama,History,Romance'],
#  ['Andrew Currie', 'Fido', 'Comedy,Drama,Horror'],
#  ['Andrew Davis', 'Above the Law', 'Action,Crime,Drama'],
#  ['Andrew Davis', 'Under Siege', 'Action,Thriller'],
#  ['Andrew Davis', 'The Fugitive', 'Action,Crime,Drama'],
#  ['Andrew Davis', 'Chain Reaction', 'Action,Drama,Sci-Fi'],
#  ['Andrew Davis', 'A Perfect Murder', 'Crime,Drama,Thriller'],
#  ['Andrew Davis', 'Collateral Damage', 'Action,Drama,Thriller'],
#  ['Andrew Davis', 'Holes', 'Adventure,Comedy,Drama'],
#  ['Andrew Davis', 'The Guardian', 'Adventure,Drama'],
#  ['Andrew Dominik', 'Chopper', 'Biography,Crime,Drama'],
#  ['Andrew Dominik',
#   'The Assassination of Jesse James by the Coward Robert Ford',
#   'Biography,Crime,Drama'],
#  ['Andrew Dominik', 'Killing Them Softly', 'Crime,Drama,Thriller'],
#  ['Andrew Douglas', 'The Amityville Horror', 'Horror'],
#  ['Andrew Erwin', "Moms' Night Out", 'Comedy'],
#  ['Andrew Erwin', 'I Can Only Imagine', 'Biography,Drama,Family'],
#  ['Andrew Fleming', 'Threesome', 'Comedy,Drama,Romance'],
#  ['Andrew Fleming', 'The Craft', 'Drama,Fantasy,Horror'],
#  ['Andrew Fleming', 'Dick', 'Comedy'],
#  ['Andrew Fleming', 'The In-Laws', 'Action,Comedy,Thriller'],
#  ['Andrew Fleming', 'Nancy Drew', 'Comedy,Crime,Family'],
#  ['Andrew Fleming', 'Hamlet 2', 'Comedy,Music'],
#  ['Andrew Fleming', 'Barefoot', 'Comedy,Drama,Romance'],
#  ['Andrew Fleming', 'Younger', 'Comedy,Romance'],
#  ['Andrew Fleming', 'Insatiable', 'Comedy,Drama,Thriller'],
#  ['Andrew Gunn', 'Green Wing', 'Comedy,Drama'],
#  ['Andrew Haigh', 'Weekend', 'Drama,Romance'],
#  ['Andrew Haigh', 'Looking', 'Comedy,Drama,Romance'],
#  ['Andrew Haigh', '45 Years', 'Drama,Romance'],
#  ['Andrew Jarecki', 'Capturing the Friedmans', 'Biography,Documentary'],
#  ['Andrew Jarecki', 'All Good Things', 'Crime,Drama,Mystery'],
#  ['Andrew Jarecki',
#   'The Jinx: The Life and Deaths of Robert Durst',
#   'Crime,Documentary'],
#  ['Andrew Jay Cohen', 'The House', 'Comedy,Crime'],
#  ['Andrew L. Schmidt',
#   'Trollhunters: Tales of Arcadia',
#   'Action,Adventure,Animation'],
#  ['Andrew Lau', 'Infernal Affairs II', 'Action,Crime,Drama'],
#  ['Andrew Lau', 'Infernal Affairs III', 'Action,Crime,Drama'],
#  ['Andrew Lau', 'The Flock', 'Crime,Drama,Mystery'],
#  ['Andrew McCarthy', 'Orange Is the New Black', 'Comedy,Crime,Drama'],
#  ['Andrew Mogel', 'The D Train', 'Comedy,Drama'],
#  ['Andrew Morahan',
#   'Highlander: The Final Dimension',
#   'Action,Fantasy,Romance'],
#  ['Andrew Morahan', 'Goal! III', 'Action,Adventure,Drama'],
#  ['Andrew Niccol', 'Gattaca', 'Drama,Sci-Fi,Thriller'],
#  ['Andrew Niccol', 'S1m0ne', 'Comedy,Drama,Sci-Fi'],
#  ['Andrew Niccol', 'Lord of War', 'Action,Crime,Drama'],
#  ['Andrew Niccol', 'The Host', 'Action,Adventure,Drama'],
#  ['Andrew Niccol', 'In Time', 'Action,Crime,Sci-Fi'],
#  ['Andrew Niccol', 'Good Kill', 'Drama,Thriller,War'],
#  ['Andrew Niccol', 'Anon', 'Action,Crime,Drama'],
#  ['Andrew Sipes', 'Fair Game', 'Action,Crime,Romance'],
#  ['Andrew Stanton', 'John Carter', 'Action,Adventure,Sci-Fi'],
#  ['Andrew Stanton', 'WALL·E', 'Adventure,Animation,Family'],
#  ['Andrew Stanton', 'Finding Dory', 'Adventure,Animation,Comedy'],
#  ['Andrew Stanton', 'Chapter Five: Dig Dug', 'Drama,Fantasy,Horror'],
#  ['Andrew Stanton', 'Chapter Six: The Spy', 'Drama,Fantasy,Horror'],
#  ['Andrew Traucki', 'The Reef', 'Adventure,Drama,Horror'],
#  ['Andrew V. McLaglen', 'McLintock!', 'Comedy,Romance,Western'],
#  ['Andrew V. McLaglen', 'The Wild Geese', 'Action,Adventure,Drama'],
#  ['Andrew Waller', 'American Pie Presents: Beta House', 'Comedy'],
#  ['Andrey Konchalovskiy', 'Runaway Train', 'Action,Adventure,Drama'],
#  ['Andrey Konchalovskiy', 'Tango & Cash', 'Action,Comedy,Crime'],
#  ['Andrey Konchalovskiy', 'The Odyssey', 'Adventure,Drama,Fantasy'],
#  ['Andrey Zvyagintsev', 'The Return', 'Drama'],
#  ['Andrey Zvyagintsev', 'Elena', 'Crime,Drama,Thriller'],
#  ['Andrey Zvyagintsev', 'Leviathan', 'Crime,Drama'],
#  ['Andrey Zvyagintsev', 'Loveless', 'Drama'],
#  ['Andrzej Bartkowiak', 'Romeo Must Die', 'Action,Crime,Thriller'],
#  ['Andrzej Bartkowiak', 'Exit Wounds', 'Action,Comedy,Crime'],
#  ['Andrzej Bartkowiak', 'Cradle 2 the Grave', 'Action,Crime,Drama'],
#  ['Andrzej Bartkowiak', 'Doom', 'Action,Adventure,Fantasy'],
#  ['Andrzej Bartkowiak',
#   'Street Fighter: The Legend of Chun-Li',
#   'Action,Crime,Thriller'],
#  ['Andrzej Sekula', 'Cube²: Hypercube', 'Drama,Mystery,Sci-Fi'],
#  ['Andrzej Wajda', 'Katyn', 'Drama,History,War'],
#  ['Andrzej Zulawski', 'Possession', 'Drama,Horror'],
#  ['André De Toth', 'House of Wax', 'Horror'],
#  ['André Øvredal', 'Trollhunter', 'Drama,Fantasy,Horror'],
#  ['André Øvredal', 'The Autopsy of Jane Doe', 'Horror,Mystery,Thriller'],
#  ['André Øvredal',
#   'Scary Stories to Tell in the Dark',
#   'Horror,Mystery,Thriller'],
#  ['Andrés Baiz', 'The Hidden Face', 'Drama,Mystery,Thriller'],
#  ['Andrés Baiz', 'Narcos', 'Biography,Crime,Drama'],
#  ['Andrés Baiz', 'Narcos: Mexico', 'Crime,Drama'],
#  ['Andrés Wood', 'Machuca', 'Biography,Drama,History'],
#  ['Andy Ackerman', 'Seinfeld', 'Comedy'],
#  ['Andy Ackerman', 'Becker', 'Comedy'],
#  ['Andy Ackerman', 'The New Adventures of Old Christine', 'Comedy'],
#  ['Andy Ackerman', 'Whitney', 'Comedy'],
#  ['Andy Barsh', 'The Daily Show', 'Comedy,News,Talk-Show'],
#  ['Andy Cadiff', 'Spin City', 'Comedy'],
#  ['Andy Cadiff', 'Chasing Liberty', 'Comedy,Romance'],
#  ['Andy Cadiff', 'Young & Hungry', 'Comedy,Drama,Romance'],
#  ['Andy De Emmony', 'Father Ted', 'Comedy'],
#  ['Andy Fickman', "She's the Man", 'Comedy,Romance,Sport'],
#  ['Andy Fickman', 'The Game Plan', 'Comedy,Family,Sport'],
#  ['Andy Fickman', 'Parental Guidance', 'Comedy,Family'],
#  ['Andy Fickman', 'Race to Witch Mountain', 'Action,Adventure,Family'],
#  ['Andy Fickman', 'You Again', 'Comedy,Romance'],
#  ['Andy Fickman', 'Paul Blart: Mall Cop 2', 'Action,Comedy,Crime'],
#  ['Andy Goddard', 'Torchwood', 'Action,Drama,Fantasy'],
#  ['Andy Goddard', 'Dracula', 'Drama,Horror,Romance'],
#  ['Andy Goddard', 'Luke Cage', 'Action,Crime,Drama'],
#  ['Andy Hamilton', 'What We Did on Our Holiday', 'Comedy,Drama'],
#  ['Andy Hay', 'The Musketeers', 'Adventure,Drama'],
#  ['Andy Mikita', 'Stargate Universe', 'Drama,Sci-Fi'],
#  ['Andy Mikita', 'Travelers', 'Drama,Mystery,Sci-Fi'],
#  ['Andy Morris', 'Home Improvement', 'Comedy,Family'],
#  ['Andy Muschietti', 'It', 'Horror'],
#  ['Andy Muschietti', 'Mama', 'Horror,Thriller'],
#  ['Andy Muschietti', 'It Chapter Two', 'Drama,Fantasy,Horror'],
#  ['Andy Serkis', 'Mowgli: Legend of the Jungle', 'Adventure,Drama,Fantasy'],
#  ['Andy Serkis', 'Breathe', 'Biography,Drama,Romance'],
#  ['Andy Tennant', 'It Takes Two', 'Comedy,Family,Romance'],
#  ['Andy Tennant', 'Fools Rush In', 'Comedy,Drama,Romance'],
#  ['Andy Tennant', 'Ever After: A Cinderella Story', 'Comedy,Drama,Romance'],
#  ['Andy Tennant', 'Anna and the King', 'Drama,History,Romance'],
#  ['Andy Tennant', 'Sweet Home Alabama', 'Comedy,Romance'],
#  ['Andy Tennant', 'Hitch', 'Comedy,Romance'],
#  ['Andy Tennant', "Fool's Gold", 'Action,Adventure,Comedy'],
#  ['Andy Tennant', 'The Bounty Hunter', 'Action,Comedy,Romance'],
#  ['Andy Wilson', 'Ripper Street', 'Crime,Drama,Mystery'],
#  ['Andy Wolk', 'Ugly Betty', 'Comedy,Drama,Romance'],
#  ['Anees Bazmee', 'Welcome', 'Comedy,Romance'],
#  ['Anees Bazmee', 'Singh Is King', 'Action,Comedy,Crime'],
#  ['Anees Bazmee', 'Ready', 'Action,Comedy'],
#  ['Aneesh Chaganty', 'Searching', 'Drama,Mystery,Thriller'],
#  ['Ang Lee', 'The Wedding Banquet', 'Comedy,Drama,Romance'],
#  ['Ang Lee', 'Eat Drink Man Woman', 'Comedy,Drama,Romance'],
#  ['Ang Lee', 'Sense and Sensibility', 'Drama,Romance'],
#  ['Ang Lee', 'The Ice Storm', 'Drama'],
#  ['Ang Lee', 'Ride with the Devil', 'Drama,Romance,War'],
#  ['Ang Lee', 'Crouching Tiger, Hidden Dragon', 'Action,Adventure,Fantasy'],
#  ['Ang Lee', 'Hulk', 'Action,Sci-Fi'],
#  ['Ang Lee', 'Brokeback Mountain', 'Drama,Romance'],
#  ['Ang Lee', 'Life of Pi', 'Adventure,Drama,Fantasy'],
#  ['Ang Lee', 'Lust, Caution', 'Drama,History,Romance'],
#  ['Ang Lee', 'Taking Woodstock', 'Biography,Comedy,Drama'],
#  ['Ang Lee', "Billy Lynn's Long Halftime Walk", 'Action,Drama,Sport'],
#  ['Angel Gracia', 'From Prada to Nada', 'Comedy,Drama,Romance'],
#  ['Angela Robinson', 'D.E.B.S.', 'Action,Comedy,Romance'],
#  ['Angela Robinson', 'Herbie Fully Loaded', 'Adventure,Comedy,Family'],
#  ['Angela Robinson',
#   'Professor Marston and the Wonder Women',
#   'Biography,Drama'],
#  ['Angelina Jolie', 'In the Land of Blood and Honey', 'Drama,Romance,War'],
#  ['Angelina Jolie', 'Unbroken', 'Biography,Drama,Sport'],
#  ['Angelina Jolie', 'By the Sea', 'Drama,Romance'],
#  ['Angelina Jolie', 'First They Killed My Father', 'Biography,Drama,History'],
#  ['Angus MacLane', 'Toy Story of Terror', 'Adventure,Animation,Comedy'],
#  ['Anh Hung Tran', 'Norwegian Wood', 'Drama,Romance'],
#  ['Aniruddha Roy Chowdhury', 'Pink', 'Drama,Thriller'],
#  ['Anjali Menon', 'Bangalore Days', 'Comedy,Drama,Romance'],
#  ['Ann Druyan', 'Cosmos', 'Documentary'],
#  ['Anna Boden', "It's Kind of a Funny Story", 'Comedy,Drama,Romance'],
#  ['Anna Boden', 'Mississippi Grind', 'Comedy,Drama'],
#  ['Anna Boden', 'Captain Marvel', 'Action,Adventure,Sci-Fi'],
#  ['Anna Foerster', 'Underworld: Blood Wars', 'Action,Adventure,Fantasy'],
#  ['Anna Muylaert', 'The Second Mother', 'Comedy,Drama'],
#  ['Anna Rose Holmer', 'The OA', 'Drama,Fantasy,Mystery'],
#  ['Annabel Jankel', 'Super Mario Bros.', 'Adventure,Comedy,Family'],
#  ['Anne Fletcher', 'Step Up', 'Crime,Drama,Music'],
#  ['Anne Fletcher', '27 Dresses', 'Comedy,Romance'],
#  ['Anne Fletcher', 'The Proposal', 'Comedy,Drama,Romance'],
#  ['Anne Fletcher', 'The Guilt Trip', 'Comedy,Drama'],
#  ['Anne Fletcher', 'Hot Pursuit', 'Action,Comedy,Crime'],
#  ['Anne Fletcher', "Dumplin'", 'Comedy,Drama,Musical'],
#  ['Anne Fontaine', 'Coco Before Chanel', 'Biography,Drama'],
#  ['Anne Fontaine', 'Adore', 'Drama,Romance'],
#  ['Anne Sewitsky', 'Rachel, Jack and Ashley Too', 'Drama,Sci-Fi,Thriller'],
#  ['Annie Griffin', 'Fresh Meat', 'Comedy,Drama'],
#  ['Anson Williams', 'Baywatch', 'Action,Adventure,Crime'],
#  ['Anthony Bell', 'Alpha and Omega', 'Adventure,Animation,Comedy'],
#  ['Anthony Burns', 'Home Sweet Hell', 'Comedy,Crime,Thriller'],
#  ['Anthony Byrne', 'Mr Selfridge', 'Drama'],
#  ['Anthony Byrne', 'In Darkness', 'Mystery,Thriller'],
#  ['Anthony C. Ferrante', 'Sharknado', 'Action,Adventure,Comedy'],
#  ['Anthony C. Ferrante',
#   'Sharknado 2: The Second One',
#   'Action,Adventure,Comedy'],
#  ['Anthony C. Ferrante',
#   'Sharknado 3: Oh Hell No!',
#   'Action,Adventure,Comedy'],
#  ['Anthony Chun', 'Pickle Rick', 'Adventure,Animation,Comedy'],
#  ['Anthony DiBlasi', 'Dread', 'Drama,Horror,Thriller'],
#  ['Anthony DiBlasi', 'Last Shift', 'Horror,Mystery,Thriller'],
#  ['Anthony Harvey', 'The Lion in Winter', 'Biography,Drama,History'],
#  ['Anthony Hemingway', 'Red Tails', 'Action,Drama,History'],
#  ['Anthony Hemingway', 'Heroes', 'Drama,Fantasy,Sci-Fi'],
#  ['Anthony Hemingway', 'Treme', 'Drama,Music'],
#  ['Anthony Hickox', 'Hellraiser III: Hell on Earth', 'Horror'],
#  ['Anthony Mann', "Winchester '73", 'Action,Drama,Western'],
#  ['Anthony Mann', 'El Cid', 'Biography,Drama,History'],
#  ['Anthony Maras', 'Hotel Mumbai', 'Drama,History,Thriller'],
#  ['Anthony Minghella', 'The English Patient', 'Drama,Romance,War'],
#  ['Anthony Minghella', 'The Talented Mr. Ripley', 'Crime,Drama,Thriller'],
#  ['Anthony Minghella', 'Cold Mountain', 'Adventure,Drama,History'],
#  ['Anthony Minghella', 'Breaking and Entering', 'Crime,Drama,Romance'],
#  ['Anthony Perkins', 'Psycho III', 'Horror,Mystery,Thriller'],
#  ['Anthony Pullen Shaw', 'Murder, She Wrote', 'Crime,Drama,Mystery'],
#  ['Anthony Russo', 'Welcome to Collinwood', 'Comedy,Crime'],
#  ['Anthony Russo',
#   'Captain America: The Winter Soldier',
#   'Action,Adventure,Sci-Fi'],
#  ['Anthony Russo', 'Captain America: Civil War', 'Action,Adventure,Sci-Fi'],
#  ['Anthony Russo', 'Avengers: Infinity War', 'Action,Adventure,Sci-Fi'],
#  ['Anthony Russo', 'Avengers: Endgame', 'Action,Adventure,Sci-Fi'],
#  ['Anthony Waller', 'An American Werewolf in Paris', 'Comedy,Fantasy,Horror'],
#  ['Anthony Wonke', 'Ronaldo', 'Biography,Documentary,Sport'],
#  ['Antoine Fuqua', 'The Replacement Killers', 'Action,Crime,Thriller'],
#  ['Antoine Fuqua', 'Training Day', 'Crime,Drama,Thriller'],
#  ['Antoine Fuqua', 'Bait', 'Action,Comedy,Crime'],
#  ['Antoine Fuqua', 'Tears of the Sun', 'Action,Drama,Thriller'],
#  ['Antoine Fuqua', 'King Arthur', 'Action,Adventure,Drama'],
#  ['Antoine Fuqua', 'The Equalizer', 'Action,Crime,Thriller'],
#  ['Antoine Fuqua', 'Shooter', 'Action,Drama,Thriller'],
#  ['Antoine Fuqua', "Brooklyn's Finest", 'Crime,Drama,Thriller'],
#  ['Antoine Fuqua', 'Southpaw', 'Drama,Sport'],
#  ['Antoine Fuqua', 'Olympus Has Fallen', 'Action,Thriller'],
#  ['Antoine Fuqua', 'The Magnificent Seven', 'Action,Adventure,Western'],
#  ['Antoine Fuqua', 'The Equalizer 2', 'Action,Crime,Thriller'],
#  ['Anton Corbijn', 'Control', 'Biography,Drama,Music'],
#  ['Anton Corbijn', 'The American', 'Crime,Drama,Thriller'],
#  ['Anton Corbijn', 'A Most Wanted Man', 'Crime,Drama,Thriller'],
#  ['Antonia Bird', 'Ravenous', 'Adventure,Comedy,Horror'],
#  ['Antonio Campos', 'Christine', 'Biography,Drama'],
#  ['Antonio Negret', 'Transit', 'Action,Crime,Thriller'],
#  ['Antonio Negret', 'Overdrive', 'Action,Thriller'],
#  ['Antony Hoffman', 'Red Planet', 'Action,Sci-Fi,Thriller'],
#  ['Antti Jokinen', 'The Resident', 'Drama,Horror,Mystery'],
#  ['Anubhav Sinha', 'Article 15', 'Crime,Drama'],
#  ['Anubhav Sinha', 'Ra.One', 'Action,Adventure,Sci-Fi'],
#  ['Anubhav Sinha', 'Mulk', 'Drama'],
#  ['Anup Bhandari', 'RangiTaranga', 'Mystery,Thriller'],
#  ['Anurag Basu', 'Life in a Metro', 'Comedy,Drama,Romance'],
#  ['Anurag Basu', 'Kites', 'Action,Drama,Romance'],
#  ['Anurag Basu', 'Barfi!', 'Comedy,Drama,Romance'],
#  ['Anurag Kashyap', 'Black Friday', 'Action,Crime,Drama'],
#  ['Anurag Kashyap', 'Gulaal', 'Crime,Drama,Thriller'],
#  ['Anurag Kashyap', 'Dev.D', 'Comedy,Drama,Romance'],
#  ['Anurag Kashyap', 'Gangs of Wasseypur', 'Action,Comedy,Crime'],
#  ['Anurag Kashyap', 'Ugly', 'Crime,Drama,Mystery'],
#  ['Anurag Kashyap', 'Raman Raghav 2.0', 'Crime,Drama,Thriller'],
#  ['Anurag Kashyap', 'Sacred Games', 'Action,Crime,Drama'],
#  ['Anurag Singh', 'Kesari', 'Action,Drama,History'],
#  ['Anusha Rizvi', 'Peepli (Live)', 'Comedy,Drama'],
#  ['Apichatpong Weerasethakul',
#   'Uncle Boonmee Who Can Recall His Past Lives',
#   'Drama,Fantasy'],
#  ['Apoorv Singh Karki', 'Flames', 'Comedy,Drama,Romance'],
#  ['Aram Rappaport', 'Syrup', 'Comedy,Drama,Romance'],
#  ['Arbaaz Khan', 'Dabangg 2', 'Action,Comedy'],
#  ['Archie Mayo', 'The Petrified Forest', 'Drama,Film-Noir,Romance'],
#  ['Ari Aster', 'Hereditary', 'Drama,Horror,Mystery'],
#  ['Ari Aster', 'Midsommar', 'Drama,Horror,Mystery'],
#  ['Ari Folman', 'Waltz with Bashir', 'Animation,Biography,Documentary'],
#  ['Ari Folman', 'The Congress', 'Animation,Drama,Sci-Fi'],
#  ['Ari Sandel', 'The Duff', 'Comedy,Romance'],
#  ['Ari Sandel', 'Goosebumps 2: Haunted Halloween', 'Adventure,Comedy,Family'],
#  ['Ari Sandel', 'When We First Met', 'Comedy,Fantasy,Romance'],
#  ['Arie Posin', 'The Chumscrubber', 'Comedy,Drama'],
#  ['Ariel Schulman', 'Paranormal Activity 3', 'Horror,Mystery,Thriller'],
#  ['Ariel Vromen', 'The Iceman', 'Biography,Crime,Drama'],
#  ['Ariel Vromen', 'Criminal', 'Action,Crime,Drama'],
#  ['Ariel Zeitoun', 'Yamakasi', 'Action,Crime,Drama'],
#  ['Aristomenis Tsirbas', 'Battle for Terra', 'Action,Adventure,Animation'],
#  ['Armando Iannucci', 'In the Loop', 'Comedy'],
#  ['Armando Iannucci', 'The Death of Stalin', 'Comedy,Drama,History'],
#  ['Arne Glimcher', 'Just Cause', 'Action,Crime,Drama'],
#  ['Art Linson', 'Where the Buffalo Roam', 'Biography,Comedy'],
#  ['Arthur Allan Seidelman',
#   'Hercules in New York',
#   'Adventure,Family,Fantasy'],
#  ['Arthur Davis', 'The Jetsons', 'Animation,Comedy,Family'],
#  ['Arthur Forrest', 'Whose Line Is It Anyway?', 'Comedy,Game-Show'],
#  ['Arthur Hiller', 'Love Story', 'Drama,Romance'],
#  ['Arthur Hiller', 'Silver Streak', 'Action,Comedy,Crime'],
#  ['Arthur Hiller', 'See No Evil, Hear No Evil', 'Comedy,Crime'],
#  ['Arthur Penn', 'The Miracle Worker', 'Biography,Drama'],
#  ['Arthur Penn', 'Bonnie and Clyde', 'Action,Biography,Crime'],
#  ['Arthur Penn', 'Little Big Man', 'Adventure,Comedy,Drama'],
#  ['Arthur Penn', 'Night Moves', 'Crime,Mystery,Thriller'],
#  ['Arthur Qwak', 'Dragon Hunters', 'Action,Adventure,Animation'],
#  ['Arthur Rankin Jr.',
#   "Santa Claus Is Comin' to Town",
#   'Adventure,Animation,Comedy'],
#  ['Arvin Brown', 'Everwood', 'Drama'],
#  ['Asger Leth', 'Man on a Ledge', 'Action,Adventure,Crime'],
#  ['Asghar Farhadi', 'About Elly', 'Drama,Mystery,Thriller'],
#  ['Asghar Farhadi', 'A Separation', 'Drama,Thriller'],
#  ['Asghar Farhadi', 'The Past', 'Drama,Mystery'],
#  ['Asghar Farhadi', 'Everybody Knows', 'Crime,Drama,Mystery'],
#  ['Asghar Farhadi', 'The Salesman', 'Drama,Thriller'],
#  ['Ash Brannon', "Surf's Up", 'Animation,Comedy,Family'],
#  ['Ashley Way', 'Merlin', 'Adventure,Drama,Fantasy'],
#  ['Ashraf Ismail',
#   "Assassin's Creed IV: Black Flag",
#   'Action,Adventure,History'],
#  ['Ashutosh Gowariker',
#   'Lagaan: Once Upon a Time in India',
#   'Adventure,Drama,Musical'],
#  ['Ashutosh Gowariker', 'Swades', 'Drama'],
#  ['Ashutosh Gowariker', 'Jodhaa Akbar', 'Action,Drama,History'],
#  ['Ashwiny Iyer Tiwari', 'Bareilly Ki Barfi', 'Comedy,Romance'],
#  ['Asif Kapadia', 'The Return', 'Horror,Mystery,Thriller'],
#  ['Asif Kapadia', 'Senna', 'Biography,Documentary,Sport'],
#  ['Asif Kapadia', 'Amy', 'Biography,Documentary,Music'],
#  ['Assaf Bernstein', 'Fauda', 'Action,Drama,Thriller'],
#  ['Assaf Bernstein', 'Look Away', 'Horror,Thriller'],
#  ['Ate de Jong', 'Drop Dead Fred', 'Comedy,Drama,Fantasy'],
#  ['Atif Yilmaz', 'Feyzo, the Polite One', 'Comedy,Romance'],
#  ['Atif Yilmaz', 'The Girl with the Red Scarf', 'Drama,Romance'],
#  ['Atlee Kumar', 'Theri', 'Action,Drama'],
#  ['Atlee Kumar', 'Mersal', 'Action,Thriller'],
#  ['Atom Egoyan', 'Exotica', 'Drama'],
#  ['Atom Egoyan', 'The Sweet Hereafter', 'Drama'],
#  ['Atom Egoyan', 'Ararat', 'Drama,War'],
#  ['Atom Egoyan', 'Where the Truth Lies', 'Crime,Drama,Mystery'],
#  ['Atom Egoyan', "Devil's Knot", 'Biography,Crime,Drama'],
#  ['Atom Egoyan', 'Chloe', 'Drama,Mystery,Romance'],
#  ['Atom Egoyan', 'The Captive', 'Crime,Drama,Mystery'],
#  ['Atom Egoyan', 'Remember', 'Drama,Mystery,Thriller'],
#  ['Audrey Cooke', 'Midsomer Murders', 'Crime,Drama,Mystery'],
#  ['Audrey Wells', 'Under the Tuscan Sun', 'Comedy,Drama,Romance'],
#  ['Ava DuVernay', 'Selma', 'Biography,Drama,History'],
#  ['Ava DuVernay', 'A Wrinkle in Time', 'Adventure,Family,Fantasy'],
#  ['Ava DuVernay', '13th', 'Crime,Documentary,News'],
#  ['Ava DuVernay', 'When They See Us', 'Biography,Drama,History'],
#  ['Ayan Mukherjee', 'Wake Up Sid', 'Comedy,Drama,Romance'],
#  ['Ayan Mukherjee', 'Yeh Jawaani Hai Deewani', 'Comedy,Drama,Musical'],
#  ['Aytaç Agirlar', 'Incir Reçeli', 'Drama,Romance'],
#  ['Aziz Mirza', 'Yes Boss', 'Comedy,Drama,Musical'],
#  ['Aziz Mirza', 'Chalte Chalte', 'Drama,Romance'],
#  ['Babak Anvari', 'Under the Shadow', 'Drama,Horror,Thriller'],
#  ['Babak Najafi', 'London Has Fallen', 'Action,Thriller'],
#  ['Bahman Ghobadi', 'Turtles Can Fly', 'Drama,War'],
#  ['Baillie Walsh', 'Flashbacks of a Fool', 'Drama'],
#  ['Baltasar Kormákur', '2 Guns', 'Action,Thriller'],
#  ['Baltasar Kormákur', 'Contraband', 'Action,Crime,Drama'],
#  ['Baltasar Kormákur', 'Everest', 'Action,Adventure,Biography'],
#  ['Baltasar Kormákur', 'Adrift', 'Action,Adventure,Biography'],
#  ['Banjong Pisanthanakun', 'Shutter', 'Horror,Mystery,Thriller'],
#  ['Banksy', 'Exit Through the Gift Shop', 'Comedy,Crime,Documentary'],
#  ['Baran bo Odar', 'Sleepless', 'Action,Crime,Thriller'],
#  ['Baran bo Odar', 'Who Am I', 'Crime,Drama,Mystery'],
#  ['Baran bo Odar', 'Dark', 'Crime,Drama,Mystery'],
#  ['Barbara Brown', 'The Rookie', 'Comedy,Crime,Drama'],
#  ['Barbara Kopple', 'Havoc', 'Crime,Drama'],
#  ['Barbara Schroeder',
#   "Evil Genius: The True Story of America's Most Diabolical Bank Heist",
#   'Crime,Documentary'],
#  ['Barbet Schroeder', 'Barfly', 'Comedy,Drama,Romance'],
#  ['Barbet Schroeder', 'Reversal of Fortune', 'Biography,Drama,Mystery'],
#  ['Barbet Schroeder', 'Single White Female', 'Drama,Thriller'],
#  ['Barbet Schroeder', 'Kiss of Death', 'Action,Crime,Thriller'],
#  ['Barbet Schroeder', 'Desperate Measures', 'Action,Crime,Drama'],
#  ['Barbet Schroeder', 'Murder by Numbers', 'Crime,Mystery,Thriller'],
#  ['Barbra Streisand', 'Yentl', 'Drama,Musical,Romance'],
#  ['Barbra Streisand', 'The Prince of Tides', 'Drama,Romance'],
#  ['Barbra Streisand', 'The Mirror Has Two Faces', 'Comedy,Drama,Romance'],
#  ['Barry Battles', 'The Baytown Outlaws', 'Action,Comedy,Crime'],
#  ['Barry Cook', 'Walking with Dinosaurs 3D', 'Adventure,Animation,Family'],
#  ['Barry Jenkins', 'Moonlight', 'Drama'],
#  ['Barry Jenkins', 'If Beale Street Could Talk', 'Drama,Romance'],
#  ['Barry Levinson', 'Diner', 'Comedy,Drama'],
#  ['Barry Levinson', 'The Natural', 'Drama,Sport'],
#  ['Barry Levinson', 'Young Sherlock Holmes', 'Adventure,Fantasy,Mystery'],
#  ['Barry Levinson', 'Good Morning, Vietnam', 'Biography,Comedy,Drama'],
#  ['Barry Levinson', 'Rain Man', 'Drama'],
#  ['Barry Levinson', 'Bugsy', 'Biography,Crime,Drama'],
#  ['Barry Levinson', 'Toys', 'Adventure,Comedy,Drama'],
#  ['Barry Levinson', 'Disclosure', 'Drama,Thriller'],
#  ['Barry Levinson', 'Sleepers', 'Crime,Drama,Thriller'],
#  ['Barry Levinson', 'Sphere', 'Drama,Horror,Mystery'],
#  ['Barry Levinson', 'Wag the Dog', 'Comedy,Drama'],
#  ['Barry Levinson', 'Bandits', 'Comedy,Crime,Drama'],
#  ['Barry Levinson', 'Envy', 'Comedy'],
#  ['Barry Levinson', 'Man of the Year', 'Comedy,Drama,Romance'],
#  ['Barry Levinson', 'What Just Happened', 'Comedy,Drama'],
#  ['Barry Levinson', "You Don't Know Jack", 'Biography,Drama'],
#  ['Barry Levinson', 'The Bay', 'Horror,Sci-Fi,Thriller'],
#  ['Barry Levinson', 'The Wizard of Lies', 'Biography,Crime,Drama'],
#  ['Barry Skolnick', 'Mean Machine', 'Comedy,Crime,Drama'],
#  ['Barry Sonnenfeld', 'The Addams Family', 'Comedy,Fantasy'],
#  ['Barry Sonnenfeld', 'Addams Family Values', 'Comedy,Fantasy'],
#  ['Barry Sonnenfeld', 'For Love or Money', 'Comedy,Drama,Romance'],
#  ['Barry Sonnenfeld', 'Get Shorty', 'Comedy,Crime,Thriller'],
#  ['Barry Sonnenfeld', 'Men in Black', 'Action,Adventure,Comedy'],
#  ['Barry Sonnenfeld', 'Wild Wild West', 'Action,Comedy,Sci-Fi'],
#  ['Barry Sonnenfeld', 'Men in Black II', 'Action,Adventure,Comedy'],
#  ['Barry Sonnenfeld', 'Big Trouble', 'Comedy,Crime,Thriller'],
#  ['Barry Sonnenfeld', 'RV', 'Adventure,Comedy,Family'],
#  ['Barry Sonnenfeld', 'Men in Black 3', 'Action,Adventure,Comedy'],
#  ['Barry Sonnenfeld', 'Nine Lives', 'Comedy,Drama,Family'],
#  ['Barry W. Blaustein', 'The Ringer', 'Comedy,Sport'],
#  ['Bart Freundlich', 'The Rebound', 'Comedy,Romance'],
#  ['Bart Layton', 'The Imposter', 'Biography,Crime,Documentary'],
#  ['Bart Layton', 'American Animals', 'Biography,Crime,Drama'],
#  ['Baz Luhrmann', 'Strictly Ballroom', 'Comedy,Drama,Music'],
#  ['Baz Luhrmann', 'Romeo + Juliet', 'Drama,Romance'],
#  ['Baz Luhrmann', 'Moulin Rouge!', 'Drama,Musical,Romance'],
#  ['Baz Luhrmann', 'Australia', 'Adventure,Comedy,Drama'],
#  ['Baz Luhrmann', 'The Great Gatsby', 'Drama,Romance'],
#  ['Becky Martin', 'Peep Show', 'Comedy'],
#  ['Becky Martin', 'Veep', 'Comedy'],
#  ['Beeban Kidron',
#   'To Wong Foo Thanks for Everything, Julie Newmar',
#   'Comedy,Drama'],
#  ['Beeban Kidron',
#   'Bridget Jones: The Edge of Reason',
#   'Comedy,Drama,Romance'],
#  ['Bejoy Nambiar', 'Wazir', 'Action,Crime,Drama'],
#  ['Ben Affleck', 'Gone Baby Gone', 'Crime,Drama,Mystery'],
#  ['Ben Affleck', 'The Town', 'Crime,Drama,Thriller'],
#  ['Ben Affleck', 'Argo', 'Biography,Drama,Thriller'],
#  ['Ben Affleck', 'Live by Night', 'Action,Crime,Drama'],
#  ['Ben Bolt', 'Doc Martin', 'Comedy,Drama,Romance'],
#  ['Ben C. Lucas', 'OtherLife', 'Crime,Mystery,Sci-Fi'],
#  ['Ben Falcone', 'Tammy', 'Comedy,Romance'],
#  ['Ben Falcone', 'The Boss', 'Comedy'],
#  ['Ben Falcone', 'Life of the Party', 'Comedy'],
#  ['Ben Feldman', 'Superstore', 'Comedy'],
#  ['Ben Gluck', 'Brother Bear 2', 'Adventure,Animation,Comedy'],
#  ['Ben Howling', 'Cargo', 'Drama,Horror,Sci-Fi'],
#  ['Ben Ketai', '30 Days of Night: Dark Days', 'Horror,Thriller'],
#  ['Ben Lewin', 'The Sessions', 'Biography,Comedy,Drama'],
#  ['Ben Palmer', 'The Inbetweeners', 'Comedy'],
#  ['Ben Palmer', 'The Inbetweeners Movie', 'Comedy'],
#  ['Ben Palmer', 'Man Up', 'Comedy,Drama,Romance'],
#  ['Ben Ramsey', 'Blood and Bone', 'Action,Crime,Drama'],
#  ['Ben Stiller', 'Reality Bites', 'Comedy,Drama,Romance'],
#  ['Ben Stiller', 'The Cable Guy', 'Comedy,Drama,Thriller'],
#  ['Ben Stiller', 'Zoolander', 'Comedy'],
#  ['Ben Stiller', 'The Secret Life of Walter Mitty', 'Comedy,Drama,Fantasy'],
#  ['Ben Stiller', 'Tropic Thunder', 'Action,Comedy,War'],
#  ['Ben Stiller', 'Zoolander 2', 'Action,Comedy'],
#  ['Ben Stiller', 'Escape at Dannemora', 'Biography,Crime,Drama'],
#  ['Ben Taylor', 'Catastrophe', 'Comedy'],
#  ['Ben Taylor', 'Sex Education', 'Comedy,Drama'],
#  ['Ben Wheatley', 'High-Rise', 'Drama'],
#  ['Ben Wheatley', 'Kill List', 'Crime,Drama,Horror'],
#  ['Ben Wheatley', 'The ABCs of Death', 'Comedy,Horror'],
#  ['Ben Wheatley', 'Sightseers', 'Adventure,Comedy,Crime'],
#  ['Ben Wheatley', 'Free Fire', 'Action,Comedy,Crime'],
#  ['Ben Young', 'Extinction', 'Action,Drama,Sci-Fi'],
#  ['Ben Younger', 'Boiler Room', 'Crime,Drama,Thriller'],
#  ['Ben Younger', 'Prime', 'Comedy,Drama,Romance'],
#  ['Ben Younger', 'Bleed for This', 'Biography,Drama,Sport'],
#  ['Benedek Fliegauf', 'Womb', 'Drama,Romance,Sci-Fi'],
#  ['Benh Zeitlin', 'Beasts of the Southern Wild', 'Adventure,Drama,Fantasy'],
#  ['Benjamin Caron', 'The Final Problem', 'Crime,Drama,Mystery'],
#  ['Benjamin Caron', 'The Crown', 'Drama,History'],
#  ['Benjamin Christensen', 'Häxan', 'Documentary,Fantasy,Horror'],
#  ['Benjamin Statler', 'Soaked in Bleach', 'Crime,Documentary'],
#  ['Bennett Miller', 'Capote', 'Biography,Crime,Drama'],
#  ['Bennett Miller', 'Foxcatcher', 'Biography,Drama,Sport'],
#  ['Bennett Miller', 'Moneyball', 'Biography,Drama,Sport'],
#  ['Benny Boom', 'All Eyez on Me', 'Biography,Drama,Music'],
#  ['Benny Chan', 'Who Am I?', 'Action,Adventure,Comedy'],
#  ['Benny Chan', 'New Police Story', 'Action,Crime,Drama'],
#  ['Benny Chan', 'Rob-B-Hood', 'Action,Comedy,Crime'],
#  ['Benny Chan', 'Shaolin', 'Action,Drama'],
#  ['Benny Safdie', 'Good Time', 'Crime,Drama,Thriller'],
#  ['Benoit Richer', 'Batman: Arkham Origins', 'Action,Adventure,Crime'],
#  ['Bent Hamer', 'Factotum', 'Comedy,Drama,Romance'],
#  ['Bernard Derriman', "Bob's Burgers", 'Animation,Comedy'],
#  ['Bernard McEveety', 'The Incredible Hulk', 'Action,Adventure,Drama'],
#  ['Bernard Rose', 'Candyman', 'Horror,Thriller'],
#  ['Bernard Rose', 'Immortal Beloved', 'Biography,Drama,Music'],
#  ['Bernard Wiesen', 'The Brady Bunch', 'Comedy,Family'],
#  ['Bernardo Bertolucci', 'The Conformist', 'Drama'],
#  ['Bernardo Bertolucci', 'Last Tango in Paris', 'Drama,Romance'],
#  ['Bernardo Bertolucci', '1900', 'Drama,History'],
#  ['Bernardo Bertolucci', 'The Last Emperor', 'Biography,Drama,History'],
#  ['Bernardo Bertolucci', 'The Sheltering Sky', 'Adventure,Drama'],
#  ['Bernardo Bertolucci', 'Little Buddha', 'Drama'],
#  ['Bernardo Bertolucci', 'Stealing Beauty', 'Drama,Mystery,Romance'],
#  ['Bernardo Bertolucci', 'The Dreamers', 'Drama,Romance'],
#  ['Bertram van Munster', 'The Amazing Race', 'Adventure,Family,Game-Show'],
#  ['Bertrand Tavernier', 'In the Electric Mist', 'Crime,Drama,Mystery'],
#  ['Beth McCarthy-Miller', 'The Kominsky Method', 'Comedy,Short'],
#  ['Bethany Ashton Wolf', 'Forever My Girl', 'Drama,Music,Romance'],
#  ['Bethany Rooney', 'Melrose Place', 'Drama,Romance'],
#  ['Betty Thomas', 'The Brady Bunch Movie', 'Comedy'],
#  ['Betty Thomas', 'Doctor Dolittle', 'Comedy,Family,Fantasy'],
#  ['Betty Thomas', 'Private Parts', 'Biography,Comedy,Drama'],
#  ['Betty Thomas', '28 Days', 'Comedy,Drama'],
#  ['Betty Thomas', 'I Spy', 'Action,Adventure,Comedy'],
#  ['Betty Thomas', 'John Tucker Must Die', 'Comedy,Romance'],
#  ['Betty Thomas',
#   'Alvin and the Chipmunks: The Squeakquel',
#   'Animation,Comedy,Family'],
#  ['Bharat Nalluri', 'The Crow: Salvation', 'Action,Crime,Fantasy'],
#  ['Bharat Nalluri', 'Miss Pettigrew Lives for a Day', 'Comedy,Romance'],
#  ['Bharat Nalluri', 'MI-5', 'Action,Drama,Thriller'],
#  ['Bibo Bergeron', 'Shark Tale', 'Adventure,Animation,Comedy'],
#  ['Bibo Bergeron', 'A Monster in Paris', 'Adventure,Animation,Comedy'],
#  ['Bigas Luna', 'Jamón, Jamón', 'Comedy,Drama,Romance'],
#  ['Bilal Lashari', 'Waar', 'Action,Crime,Drama'],
#  ['Bill Condon', 'Gods and Monsters', 'Biography,Drama'],
#  ['Bill Condon', 'Kinsey', 'Biography,Drama,Romance'],
#  ['Bill Condon', 'Dreamgirls', 'Drama,Music,Musical'],
#  ['Bill Condon',
#   'The Twilight Saga: Breaking Dawn - Part 1',
#   'Action,Adventure,Drama'],
#  ['Bill Condon',
#   'The Twilight Saga: Breaking Dawn - Part 2',
#   'Adventure,Drama,Fantasy'],
#  ['Bill Condon', 'The Fifth Estate', 'Biography,Drama,Thriller'],
#  ['Bill Condon', 'Beauty and the Beast', 'Family,Fantasy,Musical'],
#  ['Bill Condon', 'Mr. Holmes', 'Drama,Mystery'],
#  ["Bill D'Elia", 'How to Get Away with Murder', 'Crime,Drama,Mystery'],
#  ['Bill Duke', 'Sister Act 2: Back in the Habit', 'Comedy,Family,Music'],
#  ['Bill Eagles', 'Battlestar Galactica', 'Action,Adventure,Drama'],
#  ['Bill Forsyth', 'Local Hero', 'Comedy,Drama'],
#  ['Bill Hader', 'Barry', 'Action,Comedy,Crime'],
#  ['Bill Holderman', 'Book Club', 'Comedy,Drama,Romance'],
#  ['Bill Kroyer',
#   'FernGully: The Last Rainforest',
#   'Adventure,Animation,Family'],
#  ['Bill Melendez', 'A Charlie Brown Christmas', 'Animation,Comedy,Family'],
#  ['Bill Melendez',
#   "It's the Great Pumpkin, Charlie Brown",
#   'Animation,Comedy,Family'],
#  ['Bill Paxton', 'Frailty', 'Crime,Drama,Thriller'],
#  ['Bill Paxton', 'The Greatest Game Ever Played', 'Biography,Drama,History'],
#  ['Bill Pohlad', 'Love & Mercy', 'Biography,Drama,Music'],
#  ['Bill Wolf', 'Teenage Mutant Ninja Turtles', 'Action,Adventure,Animation'],
#  ['Bille August', 'The House of the Spirits', 'Drama,Romance'],
#  ['Bille August', 'Les Misérables', 'Crime,Drama,History'],
#  ['Bille August', "Smilla's Sense of Snow", 'Crime,Drama,Mystery'],
#  ['Bille August', 'Goodbye Bafana', 'Biography,Drama,History'],
#  ['Bille August', 'Night Train to Lisbon', 'Mystery,Romance,Thriller'],
#  ['Bille Woodruff', 'Honey', 'Drama,Music,Romance'],
#  ['Bille Woodruff', 'Beauty Shop', 'Comedy'],
#  ['Billy Bob Thornton', 'Sling Blade', 'Drama'],
#  ['Billy Bob Thornton', 'All the Pretty Horses', 'Drama,Romance,Western'],
#  ['Billy Corben', 'Cocaine Cowboys', 'Crime,Documentary,History'],
#  ['Billy Crystal', 'Forget Paris', 'Comedy,Romance'],
#  ['Billy Crystal', '61*', 'Biography,Drama,History'],
#  ['Billy Gierhart', 'Breakout Kings', 'Crime,Drama,Thriller'],
#  ["Billy O'Brien", 'I Am Not a Serial Killer', 'Drama,Horror,Thriller'],
#  ['Billy Ray', 'Shattered Glass', 'Drama,History'],
#  ['Billy Ray', 'Breach', 'Biography,Crime,Drama'],
#  ['Billy Ray', 'Secret in Their Eyes', 'Crime,Drama,Mystery'],
#  ['Billy Wilder', 'Double Indemnity', 'Crime,Drama,Film-Noir'],
#  ['Billy Wilder', 'The Lost Weekend', 'Drama,Film-Noir'],
#  ['Billy Wilder', 'Sunset Blvd.', 'Drama,Film-Noir'],
#  ['Billy Wilder', 'Ace in the Hole', 'Drama,Film-Noir'],
#  ['Billy Wilder', 'Stalag 17', 'Comedy,Drama,War'],
#  ['Billy Wilder', 'Sabrina', 'Comedy,Drama,Romance'],
#  ['Billy Wilder', 'The Seven Year Itch', 'Comedy,Romance'],
#  ['Billy Wilder', 'Love in the Afternoon', 'Comedy,Crime,Drama'],
#  ['Billy Wilder', 'Witness for the Prosecution', 'Crime,Drama,Film-Noir'],
#  ['Billy Wilder', 'Some Like It Hot', 'Comedy,Music,Romance'],
#  ['Billy Wilder', 'The Apartment', 'Comedy,Drama,Romance'],
#  ['Billy Wilder', 'One, Two, Three', 'Comedy'],
#  ['Billy Wilder', 'Irma la Douce', 'Comedy,Romance'],
#  ['Billy Wilder', 'The Fortune Cookie', 'Comedy,Romance'],
#  ['Billy Wilder', 'The Front Page', 'Comedy,Drama,Romance'],
#  ['Biswapati Sarkar', 'Permanent Roommates', 'Comedy,Romance'],
#  ['Björn Runge', 'The Wife', 'Drama'],
#  ['Blair Hayes', 'Bubble Boy', 'Adventure,Comedy,Romance'],
#  ['Blake Edwards', 'Operation Petticoat', 'Comedy,Romance,War'],
#  ['Blake Edwards', "Breakfast at Tiffany's", 'Comedy,Drama,Romance'],
#  ['Blake Edwards', 'Days of Wine and Roses', 'Drama'],
#  ['Blake Edwards', 'The Pink Panther', 'Comedy,Crime,Romance'],
#  ['Blake Edwards', 'A Shot in the Dark', 'Comedy,Mystery'],
#  ['Blake Edwards', 'The Great Race', 'Action,Adventure,Comedy'],
#  ['Blake Edwards', 'The Party', 'Comedy'],
#  ['Blake Edwards', 'The Return of the Pink Panther', 'Comedy,Crime,Mystery'],
#  ['Blake Edwards', 'The Pink Panther Strikes Again', 'Comedy,Crime'],
#  ['Blake Edwards', 'Revenge of the Pink Panther', 'Comedy,Crime,Mystery'],
#  ['Blake Edwards', '10', 'Comedy,Romance'],
#  ['Blake Edwards', 'Victor Victoria', 'Comedy,Music,Musical'],
#  ['Blake Edwards', 'Blind Date', 'Comedy,Romance'],
#  ['Bo Burnham', 'Eighth Grade', 'Comedy,Drama'],
#  ['Bo Welch', 'The Cat in the Hat', 'Adventure,Comedy,Family'],
#  ['Bo Zenga', 'Stan Helsing', 'Comedy,Horror'],
#  ['Boaz Yakin', 'Fresh', 'Crime,Drama,Thriller'],
#  ['Boaz Yakin', 'Remember the Titans', 'Biography,Drama,Sport'],
#  ['Boaz Yakin', 'Uptown Girls', 'Comedy,Drama,Romance'],
#  ['Boaz Yakin', 'Safe', 'Action,Crime,Thriller'],
#  ['Boaz Yakin', 'Max', 'Adventure,Drama,Family'],
#  ['Bob Arkwright',
#   'He-Man and the Masters of the Universe',
#   'Action,Adventure,Animation'],
#  ['Bob Camp', 'The Ren & Stimpy Show', 'Animation,Comedy,Family'],
#  ['Bob Clark', 'Black Christmas', 'Horror,Mystery,Thriller'],
#  ['Bob Clark', "Porky's", 'Comedy'],
#  ['Bob Clark', 'A Christmas Story', 'Comedy,Family'],
#  ['Bob Clark', "Porky's II: The Next Day", 'Comedy'],
#  ['Bob Clark', 'Baby Geniuses', 'Comedy,Crime,Family'],
#  ['Bob Clark', 'Superbabies: Baby Geniuses 2', 'Comedy,Family,Sci-Fi'],
#  ['Bob Dolman', 'The Banger Sisters', 'Comedy,Drama'],
#  ['Bob Fosse', 'Cabaret', 'Drama,Musical'],
#  ['Bob Fosse', 'Lenny', 'Biography,Drama'],
#  ['Bob Fosse', 'All That Jazz', 'Drama,Music,Musical'],
#  ['Bob Gale', 'Interstate 60: Episodes of the Road', 'Adventure,Comedy,Drama'],
#  ['Bob Hathcock', 'DuckTales', 'Adventure,Animation,Comedy'],
#  ['Bob Hathcock',
#   'DuckTales the Movie: Treasure of the Lost Lamp',
#   'Adventure,Animation,Comedy'],
#  ['Bob Koherr', 'Baby Daddy', 'Comedy,Drama,Family'],
#  ['Bob Odenkirk', "Let's Go to Prison", 'Comedy,Crime'],
#  ['Bob Odenkirk', 'The Brothers Solomon', 'Comedy'],
#  ['Bob Rafelson', 'Five Easy Pieces', 'Drama'],
#  ...]

# %% [markdown]
# ## Obtaining  a list of all movies released after their director death

# %%
def late_released_movies(db_cursor):
    """return the list of dictionaries with all movies released after their director death"""
    query = db_cursor.execute(
        """
        SELECT title, directors.name
        FROM directors
        JOIN movies ON movies.director_id = directors.id
        WHERE start_year > death_year
        /*LIMIT 5*/
        ORDER BY title
        """
    )
    rows = query.fetchall()

    print(f"""
       {type(rows) = }
       {len(rows) = }
       {[row.keys() for row in rows][0] = }
       """)
    key_list = [row.keys() for row in rows][0]
    return [{key_list[0]: row[key_list[0]], key_list[1]: row[key_list[1]]} for row in rows]

late_released_movies(db_cursor=cursor)
# Out:
#        type(rows) = <class 'list'>
#        len(rows) = 6
#        [row.keys() for row in rows][0] = ['title', 'name']
# [{'title': 'Cars', 'name': 'Joe Ranft'},
#  {'title': 'Fantasia 2000', 'name': 'James Algar'},
#  {'title': 'Game of Death', 'name': 'Bruce Lee'},
#  {'title': 'The Many Adventures of Winnie the Pooh', 'name': 'John Lounsbery'},
#  {'title': 'The Rescuers', 'name': 'John Lounsbery'},
#  {'title': 'Waitress', 'name': 'Adrienne Shelly'}]

# %% [markdown]
# ## Obtaining  a dictionary of stats for a given genre

# %%
def stats_on(db_cursor, genre_name):
    """return a dict of stats for a given genre"""
    query = db_cursor.execute(
        """
        SELECT genres, COUNT(*) AS number_of_movies,
        ROUND(AVG(minutes), 2) AS avg_length
        FROM movies
        WHERE genres = ?
        """,
        (genre_name,)
    )
    rows = query.fetchall()

    print(f"""
           {type(rows) = }
           {len(rows) = }
           {[row.keys() for row in rows][0] = }
           """)

    keys = [row.keys() for row in rows][0]
    stats_dict = {}

    for key in keys:
        for row in rows:
            stats_dict[key] = row[key]

    return stats_dict

stats_on(db_cursor=cursor, genre_name="Comedy")
# Out:
#            type(rows) = <class 'list'>
#            len(rows) = 1
#            [row.keys() for row in rows][0] = ['genres', 'number_of_movies', 'avg_length']
# {'genres': 'Comedy', 'number_of_movies': 367, 'avg_length': 82.69}

# %% [markdown]
# ## Obtaining a list of lists with top 5 directors of a selected genre

# %%
def top_five_directors_for(db_cursor, genre_name):
    """return the top 5 of the directors with the most movies for a given genre"""
    query = db_cursor.execute(
        """
        SELECT name, COUNT(title) AS movie_count
        FROM movies
        JOIN directors ON directors.id = movies.director_id
        WHERE genres = ?
        GROUP BY name
        ORDER BY movie_count DESC, name        
        LIMIT 5
        """,
        (genre_name,)
    )
    rows = query.fetchall()

    print(f"""
           {type(rows) = }
           {len(rows) = }
           {[row.keys() for row in rows][0] = }
           """)
    return [[row[key] for key in row.keys()] for row in rows]

top_five_directors_for(db_cursor=cursor, genre_name="Horror")
# Out:
#            type(rows) = <class 'list'>
#            len(rows) = 5
#            [row.keys() for row in rows][0] = ['name', 'movie_count']
# [['Lucio Fulci', 4],
#  ['Rob Zombie', 4],
#  ["Declan O'Brien", 3],
#  ['Eli Roth', 3],
#  ['Tobe Hooper', 3]]

# %% [markdown]
# ## Creating and exporting a csv to work in Power BI

# %%
query = """
        SELECT title,
        rating,
        vote_count,
        start_year,
        minutes,
        genres,
        name,
        birth_year,
        death_year 
        FROM movies
        JOIN directors ON directors.id = movies.director_id;
        """

movies = pd.read_sql(query, connection)
movies.to_csv("data/csv_movies.csv", index=False)

# %% [markdown]
# ## Creating and exporting 2 csv to work in Power BI (both tables in the database)

# %%
query_exploring = """
        SELECT name FROM sqlite_master  
        WHERE type='table';
        """

cursor.execute(query_exploring)
rows = cursor.fetchall()
print(rows)

for index, row in enumerate(rows[1::]):
    print(f"""{index}_{row[0]}""")
    query_table = f"""
            SELECT * FROM {row[0]}  
            """
    print(query_table)
    movies = pd.read_sql(query_table, connection)
    movies.to_csv(f"data/csv_movies_{row[0]}.csv", index=False)
# Out:
# [<sqlite3.Row object at 0x7f9135a6f5e0>, <sqlite3.Row object at 0x7f9135a6d6c0>, <sqlite3.Row object at 0x7f9135a6e5f0>]
# 0_directors
#
#             SELECT * FROM directors
#
# 1_movies
#
#             SELECT * FROM movies
